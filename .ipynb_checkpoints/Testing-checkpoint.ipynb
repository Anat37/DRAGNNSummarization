# %%
from utils import *
from model import build_decoder_model

# %load_ext autoreload
# %autoreload 2
# Out:
# c:\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
vocab = Vocab("finished_files/vocab", VOCAB_SIZE)
# Out:
# Warning: incorrectly formatted line in vocabulary file: 0800В 555В 111 356
#
#
# Warning: incorrectly formatted line in vocabulary file: 1800В 333В 000 139
#
#
# Warning: incorrectly formatted line in vocabulary file: 2В 1/2 124
#
#
# Warning: incorrectly formatted line in vocabulary file: 3В 1/2 86
#
#
# max_size of vocab was specified as 50000; we now have 50000 words. Stopping reading.
# Finished constructing vocabulary of 50000 total words. Last word added: perisic

# %%
model = build_decoder_model(None)
model.load_model("loss3")
torch.cuda.memory_allocated()
# Out:
# 271219712

# %%
class TestBatcher():
    
    def __init__(self, vocab, filename, max_article_len, max_target_len):
        generator = example_gen(filename)

        unknown_words_cnt = 0
        self.articles = []
        self.targets = []
        self.unknown_words = []
        self.batches = []
        while True:
            
            try:
                article_text, abstract_text = next(generator)
                
                article_ids, unknown_words_list = article2ids(article_text, vocab)
                art_len = min(max_article_len, len(article_ids))
                article_ids = article_ids[:art_len]
                
                target = abstract2ids(abstract_text, vocab, unknown_words_list)
                tar_len = min(max_target_len, len(target))
                target.append(STOP_DECODING_ID)
                target = target[:tar_len]
                
                
                self.articles.append(np.array([article_ids]).T)
                self.targets.append(np.array(target))
                self.unknown_words.append(unknown_words_list)
                unknown_words_cnt = max(len(unknown_words_list), unknown_words_cnt)
                self.batches.append((np.array([article_ids]).T, np.array(target), unknown_words_list))
                #print(article_text)
            except:
                break
        print(len(self.batches))
        print(unknown_words_cnt)
    
    def generator(self):
        for batch in self.batches:
            yield batch

# %%
test_data = TestBatcher(vocab, "finished_files/test.bin", 400, 120)
# Out:
# 11490
# 193

# %%
import codecs
from beam_search import run_beam_search
import os

def test_generate(model, data, beam_width, mod=0):  
    model.train(False)
    sbleu = 0
    with torch.autograd.set_grad_enabled(False):
        for i, (article_text, target, unk_words) in enumerate(data.generator()):
            #result = generate_summary(article_text, model, beam_width)
            
            '''X_batch = LongTensor(article_text)
            inputs = InputLayerState("input", True, X_batch)
            batch_size = X_batch.shape[1]
            symbols = LongTensor([[START_DECODING_ID]*batch_size])
            result = []
            model.eval_run_encoder(inputs, beam_search=False)
            for k in range(100):
                hidden = model.decode(symbols)
                symbols = hidden.argmax(-1)
                result.append(symbols.squeeze(0).item())
            '''
            result = run_beam_search(model, vocab, article_text, beam_width, 100)
            #print(result)
            #print(target)
            
            target = clean_sentence(target)
            result = clean_sentence(result)
            bleu = sentence_bleu([result], target, weights=(0.5, 0.5, 0., 0.))
            result = outputids2words(result, vocab, unk_words)
            target = outputids2words(target, vocab, unk_words)
            #print('{:.4f}'.format(bleu))
            sbleu += bleu
            '''if (bleu < 1e-3):
                print(result)
                print(0)
                print(target)'''
            #print(result.split())
            #print('target is \n')
            #print(target.split())
            if not os.access('refs' + str(mod), os.F_OK):
                os.mkdir('refs' + str(mod), 777)
            if not os.access('res' + str(mod), os.F_OK):
                os.mkdir('res' + str(mod), 777)
            with codecs.open('refs' + str(mod) + '/ref.' + str(i) +'.txt', 'w', encoding='utf8') as reference_file:
                sentences = target.split('.')
                for s in sentences:
                    reference_file.write(s.strip() + '.\n')
                
                
            with codecs.open('res' + str(mod) + '/res.' + str(i) + '.txt', 'w', encoding='utf8') as result_file:
                sentences = result.split('.')
                for s in sentences:
                    result_file.write(s.strip() + '.\n')
        print(sbleu/1000)

# %%
test_generate(model,test_data, beam_width=4)
# Out:
# c:\python36\lib\site-packages\nltk\translate\bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# c:\python36\lib\site-packages\nltk\translate\bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# c:\python36\lib\site-packages\nltk\translate\bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 1.3338394197303525

# %%
from pyrouge import Rouge155

r = Rouge155()
r.system_dir = 'E:/NIR/drag/res0'
r.model_dir = 'E:/NIR/drag/refs0'
r.system_filename_pattern = 'res.(\d+).txt'
r.model_filename_pattern = 'ref.#ID#.txt'

output = r.convert_and_evaluate()
print(output)
output_dict = r.output_to_dict(output)
# Out:
# 2019-05-17 16:29:00,764 [MainThread  ] [INFO ]  Writing summaries.
# 2019-05-17 16:29:00,766 [MainThread  ] [INFO ]  Processing summaries. Saving system files to C:\Users\Anatoly\AppData\Local\Temp\tmpnven7vn7\system and model files to C:\Users\Anatoly\AppData\Local\Temp\tmpnven7vn7\model.
# 2019-05-17 16:29:00,767 [MainThread  ] [INFO ]  Processing files in E:/NIR/drag/res0.
# 2019-05-17 16:29:00,778 [MainThread  ] [INFO ]  Processing res.0.txt.
# 2019-05-17 16:29:00,787 [MainThread  ] [INFO ]  Processing res.1.txt.
# 2019-05-17 16:29:00,795 [MainThread  ] [INFO ]  Processing res.10.txt.
# 2019-05-17 16:29:00,812 [MainThread  ] [INFO ]  Processing res.100.txt.
# 2019-05-17 16:29:00,820 [MainThread  ] [INFO ]  Processing res.1000.txt.
# 2019-05-17 16:29:00,828 [MainThread  ] [INFO ]  Processing res.10000.txt.
# 2019-05-17 16:29:00,834 [MainThread  ] [INFO ]  Processing res.10001.txt.
# 2019-05-17 16:29:00,840 [MainThread  ] [INFO ]  Processing res.10002.txt.
# 2019-05-17 16:29:00,845 [MainThread  ] [INFO ]  Processing res.10003.txt.
# 2019-05-17 16:29:00,851 [MainThread  ] [INFO ]  Processing res.10004.txt.
# 2019-05-17 16:29:00,856 [MainThread  ] [INFO ]  Processing res.10005.txt.
# 2019-05-17 16:29:00,862 [MainThread  ] [INFO ]  Processing res.10006.txt.
# 2019-05-17 16:29:00,868 [MainThread  ] [INFO ]  Processing res.10007.txt.
# 2019-05-17 16:29:00,873 [MainThread  ] [INFO ]  Processing res.10008.txt.
# 2019-05-17 16:29:00,879 [MainThread  ] [INFO ]  Processing res.10009.txt.
# 2019-05-17 16:29:00,884 [MainThread  ] [INFO ]  Processing res.1001.txt.
# 2019-05-17 16:29:00,892 [MainThread  ] [INFO ]  Processing res.10010.txt.
# 2019-05-17 16:29:00,897 [MainThread  ] [INFO ]  Processing res.10011.txt.
# 2019-05-17 16:29:00,903 [MainThread  ] [INFO ]  Processing res.10012.txt.
# 2019-05-17 16:29:00,908 [MainThread  ] [INFO ]  Processing res.10013.txt.
# 2019-05-17 16:29:00,914 [MainThread  ] [INFO ]  Processing res.10014.txt.
# 2019-05-17 16:29:00,919 [MainThread  ] [INFO ]  Processing res.10015.txt.
# 2019-05-17 16:29:00,925 [MainThread  ] [INFO ]  Processing res.10016.txt.
# 2019-05-17 16:29:00,931 [MainThread  ] [INFO ]  Processing res.10017.txt.
# 2019-05-17 16:29:00,936 [MainThread  ] [INFO ]  Processing res.10018.txt.
# 2019-05-17 16:29:00,942 [MainThread  ] [INFO ]  Processing res.10019.txt.
# 2019-05-17 16:29:00,948 [MainThread  ] [INFO ]  Processing res.1002.txt.
# 2019-05-17 16:29:00,956 [MainThread  ] [INFO ]  Processing res.10020.txt.
# 2019-05-17 16:29:00,962 [MainThread  ] [INFO ]  Processing res.10021.txt.
# 2019-05-17 16:29:00,967 [MainThread  ] [INFO ]  Processing res.10022.txt.
# 2019-05-17 16:29:00,974 [MainThread  ] [INFO ]  Processing res.10023.txt.
# 2019-05-17 16:29:00,979 [MainThread  ] [INFO ]  Processing res.10024.txt.
# 2019-05-17 16:29:00,985 [MainThread  ] [INFO ]  Processing res.10025.txt.
# 2019-05-17 16:29:00,990 [MainThread  ] [INFO ]  Processing res.10026.txt.
# 2019-05-17 16:29:00,996 [MainThread  ] [INFO ]  Processing res.10027.txt.
# 2019-05-17 16:29:01,001 [MainThread  ] [INFO ]  Processing res.10028.txt.
# 2019-05-17 16:29:01,007 [MainThread  ] [INFO ]  Processing res.10029.txt.
# 2019-05-17 16:29:01,013 [MainThread  ] [INFO ]  Processing res.1003.txt.
# 2019-05-17 16:29:01,021 [MainThread  ] [INFO ]  Processing res.10030.txt.
# 2019-05-17 16:29:01,026 [MainThread  ] [INFO ]  Processing res.10031.txt.
# 2019-05-17 16:29:01,032 [MainThread  ] [INFO ]  Processing res.10032.txt.
# 2019-05-17 16:29:01,038 [MainThread  ] [INFO ]  Processing res.10033.txt.
# 2019-05-17 16:29:01,043 [MainThread  ] [INFO ]  Processing res.10034.txt.
# 2019-05-17 16:29:01,049 [MainThread  ] [INFO ]  Processing res.10035.txt.
# 2019-05-17 16:29:01,055 [MainThread  ] [INFO ]  Processing res.10036.txt.
# 2019-05-17 16:29:01,060 [MainThread  ] [INFO ]  Processing res.10037.txt.
# 2019-05-17 16:29:01,066 [MainThread  ] [INFO ]  Processing res.10038.txt.
# 2019-05-17 16:29:01,071 [MainThread  ] [INFO ]  Processing res.10039.txt.
# 2019-05-17 16:29:01,077 [MainThread  ] [INFO ]  Processing res.1004.txt.
# 2019-05-17 16:29:01,085 [MainThread  ] [INFO ]  Processing res.10040.txt.
# 2019-05-17 16:29:01,091 [MainThread  ] [INFO ]  Processing res.10041.txt.
# 2019-05-17 16:29:01,096 [MainThread  ] [INFO ]  Processing res.10042.txt.
# 2019-05-17 16:29:01,102 [MainThread  ] [INFO ]  Processing res.10043.txt.
# 2019-05-17 16:29:01,107 [MainThread  ] [INFO ]  Processing res.10044.txt.
# 2019-05-17 16:29:01,112 [MainThread  ] [INFO ]  Processing res.10045.txt.
# 2019-05-17 16:29:01,118 [MainThread  ] [INFO ]  Processing res.10046.txt.
# 2019-05-17 16:29:01,124 [MainThread  ] [INFO ]  Processing res.10047.txt.
# 2019-05-17 16:29:01,130 [MainThread  ] [INFO ]  Processing res.10048.txt.
# 2019-05-17 16:29:01,136 [MainThread  ] [INFO ]  Processing res.10049.txt.
# 2019-05-17 16:29:01,142 [MainThread  ] [INFO ]  Processing res.1005.txt.
# 2019-05-17 16:29:01,150 [MainThread  ] [INFO ]  Processing res.10050.txt.
# 2019-05-17 16:29:01,157 [MainThread  ] [INFO ]  Processing res.10051.txt.
# 2019-05-17 16:29:01,162 [MainThread  ] [INFO ]  Processing res.10052.txt.
# 2019-05-17 16:29:01,168 [MainThread  ] [INFO ]  Processing res.10053.txt.
# 2019-05-17 16:29:01,174 [MainThread  ] [INFO ]  Processing res.10054.txt.
# 2019-05-17 16:29:01,179 [MainThread  ] [INFO ]  Processing res.10055.txt.
# 2019-05-17 16:29:01,184 [MainThread  ] [INFO ]  Processing res.10056.txt.
# 2019-05-17 16:29:01,190 [MainThread  ] [INFO ]  Processing res.10057.txt.
# 2019-05-17 16:29:01,196 [MainThread  ] [INFO ]  Processing res.10058.txt.
# 2019-05-17 16:29:01,202 [MainThread  ] [INFO ]  Processing res.10059.txt.
# 2019-05-17 16:29:01,208 [MainThread  ] [INFO ]  Processing res.1006.txt.
# 2019-05-17 16:29:01,219 [MainThread  ] [INFO ]  Processing res.10060.txt.
# 2019-05-17 16:29:01,225 [MainThread  ] [INFO ]  Processing res.10061.txt.
# 2019-05-17 16:29:01,230 [MainThread  ] [INFO ]  Processing res.10062.txt.
# 2019-05-17 16:29:01,236 [MainThread  ] [INFO ]  Processing res.10063.txt.
# 2019-05-17 16:29:01,241 [MainThread  ] [INFO ]  Processing res.10064.txt.
# 2019-05-17 16:29:01,247 [MainThread  ] [INFO ]  Processing res.10065.txt.
# 2019-05-17 16:29:01,252 [MainThread  ] [INFO ]  Processing res.10066.txt.
# 2019-05-17 16:29:01,258 [MainThread  ] [INFO ]  Processing res.10067.txt.
# 2019-05-17 16:29:01,264 [MainThread  ] [INFO ]  Processing res.10068.txt.
# 2019-05-17 16:29:01,269 [MainThread  ] [INFO ]  Processing res.10069.txt.
# 2019-05-17 16:29:01,275 [MainThread  ] [INFO ]  Processing res.1007.txt.
# 2019-05-17 16:29:01,284 [MainThread  ] [INFO ]  Processing res.10070.txt.
# 2019-05-17 16:29:01,290 [MainThread  ] [INFO ]  Processing res.10071.txt.
# 2019-05-17 16:29:01,295 [MainThread  ] [INFO ]  Processing res.10072.txt.
# 2019-05-17 16:29:01,301 [MainThread  ] [INFO ]  Processing res.10073.txt.
# 2019-05-17 16:29:01,306 [MainThread  ] [INFO ]  Processing res.10074.txt.
# 2019-05-17 16:29:01,312 [MainThread  ] [INFO ]  Processing res.10075.txt.
# 2019-05-17 16:29:01,318 [MainThread  ] [INFO ]  Processing res.10076.txt.
# 2019-05-17 16:29:01,323 [MainThread  ] [INFO ]  Processing res.10077.txt.
# 2019-05-17 16:29:01,329 [MainThread  ] [INFO ]  Processing res.10078.txt.
# 2019-05-17 16:29:01,334 [MainThread  ] [INFO ]  Processing res.10079.txt.
# 2019-05-17 16:29:01,339 [MainThread  ] [INFO ]  Processing res.1008.txt.
# 2019-05-17 16:29:01,347 [MainThread  ] [INFO ]  Processing res.10080.txt.
# 2019-05-17 16:29:01,352 [MainThread  ] [INFO ]  Processing res.10081.txt.
# 2019-05-17 16:29:01,358 [MainThread  ] [INFO ]  Processing res.10082.txt.
# 2019-05-17 16:29:01,364 [MainThread  ] [INFO ]  Processing res.10083.txt.
# 2019-05-17 16:29:01,370 [MainThread  ] [INFO ]  Processing res.10084.txt.
# 2019-05-17 16:29:01,376 [MainThread  ] [INFO ]  Processing res.10085.txt.
# 2019-05-17 16:29:01,382 [MainThread  ] [INFO ]  Processing res.10086.txt.
# 2019-05-17 16:29:01,388 [MainThread  ] [INFO ]  Processing res.10087.txt.
# 2019-05-17 16:29:01,394 [MainThread  ] [INFO ]  Processing res.10088.txt.
# 2019-05-17 16:29:01,402 [MainThread  ] [INFO ]  Processing res.10089.txt.
# 2019-05-17 16:29:01,407 [MainThread  ] [INFO ]  Processing res.1009.txt.
# 2019-05-17 16:29:01,416 [MainThread  ] [INFO ]  Processing res.10090.txt.
# 2019-05-17 16:29:01,421 [MainThread  ] [INFO ]  Processing res.10091.txt.
# 2019-05-17 16:29:01,428 [MainThread  ] [INFO ]  Processing res.10092.txt.
# 2019-05-17 16:29:01,433 [MainThread  ] [INFO ]  Processing res.10093.txt.
# 2019-05-17 16:29:01,439 [MainThread  ] [INFO ]  Processing res.10094.txt.
# 2019-05-17 16:29:01,445 [MainThread  ] [INFO ]  Processing res.10095.txt.
# 2019-05-17 16:29:01,451 [MainThread  ] [INFO ]  Processing res.10096.txt.
# 2019-05-17 16:29:01,457 [MainThread  ] [INFO ]  Processing res.10097.txt.
# 2019-05-17 16:29:01,463 [MainThread  ] [INFO ]  Processing res.10098.txt.
# 2019-05-17 16:29:01,468 [MainThread  ] [INFO ]  Processing res.10099.txt.
# 2019-05-17 16:29:01,476 [MainThread  ] [INFO ]  Processing res.101.txt.
# 2019-05-17 16:29:01,485 [MainThread  ] [INFO ]  Processing res.1010.txt.
# 2019-05-17 16:29:01,493 [MainThread  ] [INFO ]  Processing res.10100.txt.
# 2019-05-17 16:29:01,499 [MainThread  ] [INFO ]  Processing res.10101.txt.
# 2019-05-17 16:29:01,505 [MainThread  ] [INFO ]  Processing res.10102.txt.
# 2019-05-17 16:29:01,510 [MainThread  ] [INFO ]  Processing res.10103.txt.
# 2019-05-17 16:29:01,527 [MainThread  ] [INFO ]  Processing res.10104.txt.
# 2019-05-17 16:29:01,532 [MainThread  ] [INFO ]  Processing res.10105.txt.
# 2019-05-17 16:29:01,538 [MainThread  ] [INFO ]  Processing res.10106.txt.
# 2019-05-17 16:29:01,544 [MainThread  ] [INFO ]  Processing res.10107.txt.
# 2019-05-17 16:29:01,550 [MainThread  ] [INFO ]  Processing res.10108.txt.
# 2019-05-17 16:29:01,556 [MainThread  ] [INFO ]  Processing res.10109.txt.
# 2019-05-17 16:29:01,561 [MainThread  ] [INFO ]  Processing res.1011.txt.
# 2019-05-17 16:29:01,569 [MainThread  ] [INFO ]  Processing res.10110.txt.
# 2019-05-17 16:29:01,574 [MainThread  ] [INFO ]  Processing res.10111.txt.
# 2019-05-17 16:29:01,580 [MainThread  ] [INFO ]  Processing res.10112.txt.
# 2019-05-17 16:29:01,586 [MainThread  ] [INFO ]  Processing res.10113.txt.
# 2019-05-17 16:29:01,591 [MainThread  ] [INFO ]  Processing res.10114.txt.
# 2019-05-17 16:29:01,597 [MainThread  ] [INFO ]  Processing res.10115.txt.
# 2019-05-17 16:29:01,603 [MainThread  ] [INFO ]  Processing res.10116.txt.
# 2019-05-17 16:29:01,609 [MainThread  ] [INFO ]  Processing res.10117.txt.
# 2019-05-17 16:29:01,614 [MainThread  ] [INFO ]  Processing res.10118.txt.
# 2019-05-17 16:29:01,620 [MainThread  ] [INFO ]  Processing res.10119.txt.
# 2019-05-17 16:29:01,625 [MainThread  ] [INFO ]  Processing res.1012.txt.
# 2019-05-17 16:29:01,633 [MainThread  ] [INFO ]  Processing res.10120.txt.
# 2019-05-17 16:29:01,638 [MainThread  ] [INFO ]  Processing res.10121.txt.
# 2019-05-17 16:29:01,644 [MainThread  ] [INFO ]  Processing res.10122.txt.
# 2019-05-17 16:29:01,650 [MainThread  ] [INFO ]  Processing res.10123.txt.
# 2019-05-17 16:29:01,656 [MainThread  ] [INFO ]  Processing res.10124.txt.
# 2019-05-17 16:29:01,662 [MainThread  ] [INFO ]  Processing res.10125.txt.
# 2019-05-17 16:29:01,667 [MainThread  ] [INFO ]  Processing res.10126.txt.
# 2019-05-17 16:29:01,673 [MainThread  ] [INFO ]  Processing res.10127.txt.
# 2019-05-17 16:29:01,679 [MainThread  ] [INFO ]  Processing res.10128.txt.
# 2019-05-17 16:29:01,684 [MainThread  ] [INFO ]  Processing res.10129.txt.
# 2019-05-17 16:29:01,689 [MainThread  ] [INFO ]  Processing res.1013.txt.
# 2019-05-17 16:29:01,697 [MainThread  ] [INFO ]  Processing res.10130.txt.
# 2019-05-17 16:29:01,703 [MainThread  ] [INFO ]  Processing res.10131.txt.
# 2019-05-17 16:29:01,709 [MainThread  ] [INFO ]  Processing res.10132.txt.
# 2019-05-17 16:29:01,714 [MainThread  ] [INFO ]  Processing res.10133.txt.
# 2019-05-17 16:29:01,720 [MainThread  ] [INFO ]  Processing res.10134.txt.
# 2019-05-17 16:29:01,725 [MainThread  ] [INFO ]  Processing res.10135.txt.
# 2019-05-17 16:29:01,731 [MainThread  ] [INFO ]  Processing res.10136.txt.
# 2019-05-17 16:29:01,736 [MainThread  ] [INFO ]  Processing res.10137.txt.
# 2019-05-17 16:29:01,742 [MainThread  ] [INFO ]  Processing res.10138.txt.
# 2019-05-17 16:29:01,749 [MainThread  ] [INFO ]  Processing res.10139.txt.
# 2019-05-17 16:29:01,755 [MainThread  ] [INFO ]  Processing res.1014.txt.
# 2019-05-17 16:29:01,763 [MainThread  ] [INFO ]  Processing res.10140.txt.
# 2019-05-17 16:29:01,769 [MainThread  ] [INFO ]  Processing res.10141.txt.
# 2019-05-17 16:29:01,774 [MainThread  ] [INFO ]  Processing res.10142.txt.
# 2019-05-17 16:29:01,780 [MainThread  ] [INFO ]  Processing res.10143.txt.
# 2019-05-17 16:29:01,786 [MainThread  ] [INFO ]  Processing res.10144.txt.
# 2019-05-17 16:29:01,791 [MainThread  ] [INFO ]  Processing res.10145.txt.
# 2019-05-17 16:29:01,796 [MainThread  ] [INFO ]  Processing res.10146.txt.
# 2019-05-17 16:29:01,802 [MainThread  ] [INFO ]  Processing res.10147.txt.
# 2019-05-17 16:29:01,808 [MainThread  ] [INFO ]  Processing res.10148.txt.
# 2019-05-17 16:29:01,814 [MainThread  ] [INFO ]  Processing res.10149.txt.
# 2019-05-17 16:29:01,819 [MainThread  ] [INFO ]  Processing res.1015.txt.
# 2019-05-17 16:29:01,827 [MainThread  ] [INFO ]  Processing res.10150.txt.
# 2019-05-17 16:29:01,832 [MainThread  ] [INFO ]  Processing res.10151.txt.
# 2019-05-17 16:29:01,838 [MainThread  ] [INFO ]  Processing res.10152.txt.
# 2019-05-17 16:29:01,844 [MainThread  ] [INFO ]  Processing res.10153.txt.
# 2019-05-17 16:29:01,849 [MainThread  ] [INFO ]  Processing res.10154.txt.
# 2019-05-17 16:29:01,855 [MainThread  ] [INFO ]  Processing res.10155.txt.
# 2019-05-17 16:29:01,861 [MainThread  ] [INFO ]  Processing res.10156.txt.
# 2019-05-17 16:29:01,867 [MainThread  ] [INFO ]  Processing res.10157.txt.
# 2019-05-17 16:29:01,872 [MainThread  ] [INFO ]  Processing res.10158.txt.
# 2019-05-17 16:29:01,878 [MainThread  ] [INFO ]  Processing res.10159.txt.
# 2019-05-17 16:29:01,884 [MainThread  ] [INFO ]  Processing res.1016.txt.
# 2019-05-17 16:29:01,893 [MainThread  ] [INFO ]  Processing res.10160.txt.
# 2019-05-17 16:29:01,899 [MainThread  ] [INFO ]  Processing res.10161.txt.
# 2019-05-17 16:29:01,904 [MainThread  ] [INFO ]  Processing res.10162.txt.
# 2019-05-17 16:29:01,910 [MainThread  ] [INFO ]  Processing res.10163.txt.
# 2019-05-17 16:29:01,916 [MainThread  ] [INFO ]  Processing res.10164.txt.
# 2019-05-17 16:29:01,921 [MainThread  ] [INFO ]  Processing res.10165.txt.
# 2019-05-17 16:29:01,927 [MainThread  ] [INFO ]  Processing res.10166.txt.
# 2019-05-17 16:29:01,932 [MainThread  ] [INFO ]  Processing res.10167.txt.
# 2019-05-17 16:29:01,938 [MainThread  ] [INFO ]  Processing res.10168.txt.
# 2019-05-17 16:29:01,944 [MainThread  ] [INFO ]  Processing res.10169.txt.
# 2019-05-17 16:29:01,949 [MainThread  ] [INFO ]  Processing res.1017.txt.
# 2019-05-17 16:29:01,957 [MainThread  ] [INFO ]  Processing res.10170.txt.
# 2019-05-17 16:29:01,963 [MainThread  ] [INFO ]  Processing res.10171.txt.
# 2019-05-17 16:29:01,969 [MainThread  ] [INFO ]  Processing res.10172.txt.
# 2019-05-17 16:29:01,974 [MainThread  ] [INFO ]  Processing res.10173.txt.
# 2019-05-17 16:29:01,980 [MainThread  ] [INFO ]  Processing res.10174.txt.
# 2019-05-17 16:29:01,986 [MainThread  ] [INFO ]  Processing res.10175.txt.
# 2019-05-17 16:29:01,991 [MainThread  ] [INFO ]  Processing res.10176.txt.
# 2019-05-17 16:29:01,997 [MainThread  ] [INFO ]  Processing res.10177.txt.
# 2019-05-17 16:29:02,003 [MainThread  ] [INFO ]  Processing res.10178.txt.
# 2019-05-17 16:29:02,008 [MainThread  ] [INFO ]  Processing res.10179.txt.
# 2019-05-17 16:29:02,014 [MainThread  ] [INFO ]  Processing res.1018.txt.
# 2019-05-17 16:29:02,022 [MainThread  ] [INFO ]  Processing res.10180.txt.
# 2019-05-17 16:29:02,027 [MainThread  ] [INFO ]  Processing res.10181.txt.
# 2019-05-17 16:29:02,033 [MainThread  ] [INFO ]  Processing res.10182.txt.
# 2019-05-17 16:29:02,039 [MainThread  ] [INFO ]  Processing res.10183.txt.
# 2019-05-17 16:29:02,045 [MainThread  ] [INFO ]  Processing res.10184.txt.
# 2019-05-17 16:29:02,051 [MainThread  ] [INFO ]  Processing res.10185.txt.
# 2019-05-17 16:29:02,058 [MainThread  ] [INFO ]  Processing res.10186.txt.
# 2019-05-17 16:29:02,063 [MainThread  ] [INFO ]  Processing res.10187.txt.
# 2019-05-17 16:29:02,069 [MainThread  ] [INFO ]  Processing res.10188.txt.
# 2019-05-17 16:29:02,074 [MainThread  ] [INFO ]  Processing res.10189.txt.
# 2019-05-17 16:29:02,080 [MainThread  ] [INFO ]  Processing res.1019.txt.
# 2019-05-17 16:29:02,088 [MainThread  ] [INFO ]  Processing res.10190.txt.
# 2019-05-17 16:29:02,093 [MainThread  ] [INFO ]  Processing res.10191.txt.
# 2019-05-17 16:29:02,099 [MainThread  ] [INFO ]  Processing res.10192.txt.
# 2019-05-17 16:29:02,104 [MainThread  ] [INFO ]  Processing res.10193.txt.
# 2019-05-17 16:29:02,110 [MainThread  ] [INFO ]  Processing res.10194.txt.
# 2019-05-17 16:29:02,116 [MainThread  ] [INFO ]  Processing res.10195.txt.
# 2019-05-17 16:29:02,122 [MainThread  ] [INFO ]  Processing res.10196.txt.
# 2019-05-17 16:29:02,128 [MainThread  ] [INFO ]  Processing res.10197.txt.
# 2019-05-17 16:29:02,134 [MainThread  ] [INFO ]  Processing res.10198.txt.
# 2019-05-17 16:29:02,140 [MainThread  ] [INFO ]  Processing res.10199.txt.
# 2019-05-17 16:29:02,147 [MainThread  ] [INFO ]  Processing res.102.txt.
# 2019-05-17 16:29:02,155 [MainThread  ] [INFO ]  Processing res.1020.txt.
# 2019-05-17 16:29:02,164 [MainThread  ] [INFO ]  Processing res.10200.txt.
# 2019-05-17 16:29:02,170 [MainThread  ] [INFO ]  Processing res.10201.txt.
# 2019-05-17 16:29:02,176 [MainThread  ] [INFO ]  Processing res.10202.txt.
# 2019-05-17 16:29:02,182 [MainThread  ] [INFO ]  Processing res.10203.txt.
# 2019-05-17 16:29:02,187 [MainThread  ] [INFO ]  Processing res.10204.txt.
# 2019-05-17 16:29:02,193 [MainThread  ] [INFO ]  Processing res.10205.txt.
# 2019-05-17 16:29:02,199 [MainThread  ] [INFO ]  Processing res.10206.txt.
# 2019-05-17 16:29:02,205 [MainThread  ] [INFO ]  Processing res.10207.txt.
# 2019-05-17 16:29:02,211 [MainThread  ] [INFO ]  Processing res.10208.txt.
# 2019-05-17 16:29:02,217 [MainThread  ] [INFO ]  Processing res.10209.txt.
# 2019-05-17 16:29:02,223 [MainThread  ] [INFO ]  Processing res.1021.txt.
# 2019-05-17 16:29:02,231 [MainThread  ] [INFO ]  Processing res.10210.txt.
# 2019-05-17 16:29:02,237 [MainThread  ] [INFO ]  Processing res.10211.txt.
# 2019-05-17 16:29:02,243 [MainThread  ] [INFO ]  Processing res.10212.txt.
# 2019-05-17 16:29:02,248 [MainThread  ] [INFO ]  Processing res.10213.txt.
# 2019-05-17 16:29:02,255 [MainThread  ] [INFO ]  Processing res.10214.txt.
# 2019-05-17 16:29:02,260 [MainThread  ] [INFO ]  Processing res.10215.txt.
# 2019-05-17 16:29:02,266 [MainThread  ] [INFO ]  Processing res.10216.txt.
# 2019-05-17 16:29:02,271 [MainThread  ] [INFO ]  Processing res.10217.txt.
# 2019-05-17 16:29:02,279 [MainThread  ] [INFO ]  Processing res.10218.txt.
# 2019-05-17 16:29:02,285 [MainThread  ] [INFO ]  Processing res.10219.txt.
# 2019-05-17 16:29:02,290 [MainThread  ] [INFO ]  Processing res.1022.txt.
# 2019-05-17 16:29:02,298 [MainThread  ] [INFO ]  Processing res.10220.txt.
# 2019-05-17 16:29:02,304 [MainThread  ] [INFO ]  Processing res.10221.txt.
# 2019-05-17 16:29:02,310 [MainThread  ] [INFO ]  Processing res.10222.txt.
# 2019-05-17 16:29:02,316 [MainThread  ] [INFO ]  Processing res.10223.txt.
# 2019-05-17 16:29:02,322 [MainThread  ] [INFO ]  Processing res.10224.txt.
# 2019-05-17 16:29:02,328 [MainThread  ] [INFO ]  Processing res.10225.txt.
# 2019-05-17 16:29:02,334 [MainThread  ] [INFO ]  Processing res.10226.txt.
# 2019-05-17 16:29:02,339 [MainThread  ] [INFO ]  Processing res.10227.txt.
# 2019-05-17 16:29:02,345 [MainThread  ] [INFO ]  Processing res.10228.txt.
# 2019-05-17 16:29:02,350 [MainThread  ] [INFO ]  Processing res.10229.txt.
# 2019-05-17 16:29:02,356 [MainThread  ] [INFO ]  Processing res.1023.txt.
# 2019-05-17 16:29:02,363 [MainThread  ] [INFO ]  Processing res.10230.txt.
# 2019-05-17 16:29:02,369 [MainThread  ] [INFO ]  Processing res.10231.txt.
# 2019-05-17 16:29:02,375 [MainThread  ] [INFO ]  Processing res.10232.txt.
# 2019-05-17 16:29:02,380 [MainThread  ] [INFO ]  Processing res.10233.txt.
# 2019-05-17 16:29:02,387 [MainThread  ] [INFO ]  Processing res.10234.txt.
# 2019-05-17 16:29:02,394 [MainThread  ] [INFO ]  Processing res.10235.txt.
# 2019-05-17 16:29:02,400 [MainThread  ] [INFO ]  Processing res.10236.txt.
# 2019-05-17 16:29:02,406 [MainThread  ] [INFO ]  Processing res.10237.txt.
# 2019-05-17 16:29:02,412 [MainThread  ] [INFO ]  Processing res.10238.txt.
# 2019-05-17 16:29:02,418 [MainThread  ] [INFO ]  Processing res.10239.txt.
# 2019-05-17 16:29:02,424 [MainThread  ] [INFO ]  Processing res.1024.txt.
# 2019-05-17 16:29:02,431 [MainThread  ] [INFO ]  Processing res.10240.txt.
# 2019-05-17 16:29:02,438 [MainThread  ] [INFO ]  Processing res.10241.txt.
# 2019-05-17 16:29:02,443 [MainThread  ] [INFO ]  Processing res.10242.txt.
# 2019-05-17 16:29:02,449 [MainThread  ] [INFO ]  Processing res.10243.txt.
# 2019-05-17 16:29:02,455 [MainThread  ] [INFO ]  Processing res.10244.txt.
# 2019-05-17 16:29:02,460 [MainThread  ] [INFO ]  Processing res.10245.txt.
# 2019-05-17 16:29:02,466 [MainThread  ] [INFO ]  Processing res.10246.txt.
# 2019-05-17 16:29:02,481 [MainThread  ] [INFO ]  Processing res.10247.txt.
# 2019-05-17 16:29:02,488 [MainThread  ] [INFO ]  Processing res.10248.txt.
# 2019-05-17 16:29:02,494 [MainThread  ] [INFO ]  Processing res.10249.txt.
# 2019-05-17 16:29:02,500 [MainThread  ] [INFO ]  Processing res.1025.txt.
# 2019-05-17 16:29:02,509 [MainThread  ] [INFO ]  Processing res.10250.txt.
# 2019-05-17 16:29:02,514 [MainThread  ] [INFO ]  Processing res.10251.txt.
# 2019-05-17 16:29:02,520 [MainThread  ] [INFO ]  Processing res.10252.txt.
# 2019-05-17 16:29:02,526 [MainThread  ] [INFO ]  Processing res.10253.txt.
# 2019-05-17 16:29:02,531 [MainThread  ] [INFO ]  Processing res.10254.txt.
# 2019-05-17 16:29:02,537 [MainThread  ] [INFO ]  Processing res.10255.txt.
# 2019-05-17 16:29:02,543 [MainThread  ] [INFO ]  Processing res.10256.txt.
# 2019-05-17 16:29:02,549 [MainThread  ] [INFO ]  Processing res.10257.txt.
# 2019-05-17 16:29:02,555 [MainThread  ] [INFO ]  Processing res.10258.txt.
# 2019-05-17 16:29:02,561 [MainThread  ] [INFO ]  Processing res.10259.txt.
# 2019-05-17 16:29:02,567 [MainThread  ] [INFO ]  Processing res.1026.txt.
# 2019-05-17 16:29:02,575 [MainThread  ] [INFO ]  Processing res.10260.txt.
# 2019-05-17 16:29:02,580 [MainThread  ] [INFO ]  Processing res.10261.txt.
# 2019-05-17 16:29:02,586 [MainThread  ] [INFO ]  Processing res.10262.txt.
# 2019-05-17 16:29:02,591 [MainThread  ] [INFO ]  Processing res.10263.txt.
# 2019-05-17 16:29:02,597 [MainThread  ] [INFO ]  Processing res.10264.txt.
# 2019-05-17 16:29:02,602 [MainThread  ] [INFO ]  Processing res.10265.txt.
# 2019-05-17 16:29:02,607 [MainThread  ] [INFO ]  Processing res.10266.txt.
# 2019-05-17 16:29:02,613 [MainThread  ] [INFO ]  Processing res.10267.txt.
# 2019-05-17 16:29:02,618 [MainThread  ] [INFO ]  Processing res.10268.txt.
# 2019-05-17 16:29:02,624 [MainThread  ] [INFO ]  Processing res.10269.txt.
# 2019-05-17 16:29:02,630 [MainThread  ] [INFO ]  Processing res.1027.txt.
# 2019-05-17 16:29:02,637 [MainThread  ] [INFO ]  Processing res.10270.txt.
# 2019-05-17 16:29:02,643 [MainThread  ] [INFO ]  Processing res.10271.txt.
# 2019-05-17 16:29:02,649 [MainThread  ] [INFO ]  Processing res.10272.txt.
# 2019-05-17 16:29:02,655 [MainThread  ] [INFO ]  Processing res.10273.txt.
# 2019-05-17 16:29:02,661 [MainThread  ] [INFO ]  Processing res.10274.txt.
# 2019-05-17 16:29:02,668 [MainThread  ] [INFO ]  Processing res.10275.txt.
# 2019-05-17 16:29:02,674 [MainThread  ] [INFO ]  Processing res.10276.txt.
# 2019-05-17 16:29:02,679 [MainThread  ] [INFO ]  Processing res.10277.txt.
# 2019-05-17 16:29:02,685 [MainThread  ] [INFO ]  Processing res.10278.txt.
# 2019-05-17 16:29:02,692 [MainThread  ] [INFO ]  Processing res.10279.txt.
# 2019-05-17 16:29:02,697 [MainThread  ] [INFO ]  Processing res.1028.txt.
# 2019-05-17 16:29:02,705 [MainThread  ] [INFO ]  Processing res.10280.txt.
# 2019-05-17 16:29:02,711 [MainThread  ] [INFO ]  Processing res.10281.txt.
# 2019-05-17 16:29:02,717 [MainThread  ] [INFO ]  Processing res.10282.txt.
# 2019-05-17 16:29:02,723 [MainThread  ] [INFO ]  Processing res.10283.txt.
# 2019-05-17 16:29:02,728 [MainThread  ] [INFO ]  Processing res.10284.txt.
# 2019-05-17 16:29:02,734 [MainThread  ] [INFO ]  Processing res.10285.txt.
# 2019-05-17 16:29:02,741 [MainThread  ] [INFO ]  Processing res.10286.txt.
# 2019-05-17 16:29:02,748 [MainThread  ] [INFO ]  Processing res.10287.txt.
# 2019-05-17 16:29:02,754 [MainThread  ] [INFO ]  Processing res.10288.txt.
# 2019-05-17 16:29:02,759 [MainThread  ] [INFO ]  Processing res.10289.txt.
# 2019-05-17 16:29:02,765 [MainThread  ] [INFO ]  Processing res.1029.txt.
# 2019-05-17 16:29:02,773 [MainThread  ] [INFO ]  Processing res.10290.txt.
# 2019-05-17 16:29:02,779 [MainThread  ] [INFO ]  Processing res.10291.txt.
# 2019-05-17 16:29:02,785 [MainThread  ] [INFO ]  Processing res.10292.txt.
# 2019-05-17 16:29:02,790 [MainThread  ] [INFO ]  Processing res.10293.txt.
# 2019-05-17 16:29:02,795 [MainThread  ] [INFO ]  Processing res.10294.txt.
# 2019-05-17 16:29:02,801 [MainThread  ] [INFO ]  Processing res.10295.txt.
# 2019-05-17 16:29:02,807 [MainThread  ] [INFO ]  Processing res.10296.txt.
# 2019-05-17 16:29:02,813 [MainThread  ] [INFO ]  Processing res.10297.txt.
# 2019-05-17 16:29:02,820 [MainThread  ] [INFO ]  Processing res.10298.txt.
# 2019-05-17 16:29:02,825 [MainThread  ] [INFO ]  Processing res.10299.txt.
# 2019-05-17 16:29:02,832 [MainThread  ] [INFO ]  Processing res.103.txt.
# 2019-05-17 16:29:02,840 [MainThread  ] [INFO ]  Processing res.1030.txt.
# 2019-05-17 16:29:02,848 [MainThread  ] [INFO ]  Processing res.10300.txt.
# 2019-05-17 16:29:02,854 [MainThread  ] [INFO ]  Processing res.10301.txt.
# 2019-05-17 16:29:02,859 [MainThread  ] [INFO ]  Processing res.10302.txt.
# 2019-05-17 16:29:02,864 [MainThread  ] [INFO ]  Processing res.10303.txt.
# 2019-05-17 16:29:02,869 [MainThread  ] [INFO ]  Processing res.10304.txt.
# 2019-05-17 16:29:02,875 [MainThread  ] [INFO ]  Processing res.10305.txt.
# 2019-05-17 16:29:02,880 [MainThread  ] [INFO ]  Processing res.10306.txt.
# 2019-05-17 16:29:02,886 [MainThread  ] [INFO ]  Processing res.10307.txt.
# 2019-05-17 16:29:02,892 [MainThread  ] [INFO ]  Processing res.10308.txt.
# 2019-05-17 16:29:02,897 [MainThread  ] [INFO ]  Processing res.10309.txt.
# 2019-05-17 16:29:02,903 [MainThread  ] [INFO ]  Processing res.1031.txt.
# 2019-05-17 16:29:02,911 [MainThread  ] [INFO ]  Processing res.10310.txt.
# 2019-05-17 16:29:02,917 [MainThread  ] [INFO ]  Processing res.10311.txt.
# 2019-05-17 16:29:02,923 [MainThread  ] [INFO ]  Processing res.10312.txt.
# 2019-05-17 16:29:02,928 [MainThread  ] [INFO ]  Processing res.10313.txt.
# 2019-05-17 16:29:02,934 [MainThread  ] [INFO ]  Processing res.10314.txt.
# 2019-05-17 16:29:02,939 [MainThread  ] [INFO ]  Processing res.10315.txt.
# 2019-05-17 16:29:02,945 [MainThread  ] [INFO ]  Processing res.10316.txt.
# 2019-05-17 16:29:02,951 [MainThread  ] [INFO ]  Processing res.10317.txt.
# 2019-05-17 16:29:02,957 [MainThread  ] [INFO ]  Processing res.10318.txt.
# 2019-05-17 16:29:02,962 [MainThread  ] [INFO ]  Processing res.10319.txt.
# 2019-05-17 16:29:02,968 [MainThread  ] [INFO ]  Processing res.1032.txt.
# 2019-05-17 16:29:02,976 [MainThread  ] [INFO ]  Processing res.10320.txt.
# 2019-05-17 16:29:02,981 [MainThread  ] [INFO ]  Processing res.10321.txt.
# 2019-05-17 16:29:02,987 [MainThread  ] [INFO ]  Processing res.10322.txt.
# 2019-05-17 16:29:02,993 [MainThread  ] [INFO ]  Processing res.10323.txt.
# 2019-05-17 16:29:02,998 [MainThread  ] [INFO ]  Processing res.10324.txt.
# 2019-05-17 16:29:03,005 [MainThread  ] [INFO ]  Processing res.10325.txt.
# 2019-05-17 16:29:03,010 [MainThread  ] [INFO ]  Processing res.10326.txt.
# 2019-05-17 16:29:03,016 [MainThread  ] [INFO ]  Processing res.10327.txt.
# 2019-05-17 16:29:03,022 [MainThread  ] [INFO ]  Processing res.10328.txt.
# 2019-05-17 16:29:03,027 [MainThread  ] [INFO ]  Processing res.10329.txt.
# 2019-05-17 16:29:03,033 [MainThread  ] [INFO ]  Processing res.1033.txt.
# 2019-05-17 16:29:03,041 [MainThread  ] [INFO ]  Processing res.10330.txt.
# 2019-05-17 16:29:03,046 [MainThread  ] [INFO ]  Processing res.10331.txt.
# 2019-05-17 16:29:03,052 [MainThread  ] [INFO ]  Processing res.10332.txt.
# 2019-05-17 16:29:03,057 [MainThread  ] [INFO ]  Processing res.10333.txt.
# 2019-05-17 16:29:03,063 [MainThread  ] [INFO ]  Processing res.10334.txt.
# 2019-05-17 16:29:03,070 [MainThread  ] [INFO ]  Processing res.10335.txt.
# 2019-05-17 16:29:03,077 [MainThread  ] [INFO ]  Processing res.10336.txt.
# 2019-05-17 16:29:03,083 [MainThread  ] [INFO ]  Processing res.10337.txt.
# 2019-05-17 16:29:03,088 [MainThread  ] [INFO ]  Processing res.10338.txt.
# 2019-05-17 16:29:03,094 [MainThread  ] [INFO ]  Processing res.10339.txt.
# 2019-05-17 16:29:03,099 [MainThread  ] [INFO ]  Processing res.1034.txt.
# 2019-05-17 16:29:03,107 [MainThread  ] [INFO ]  Processing res.10340.txt.
# 2019-05-17 16:29:03,113 [MainThread  ] [INFO ]  Processing res.10341.txt.
# 2019-05-17 16:29:03,118 [MainThread  ] [INFO ]  Processing res.10342.txt.
# 2019-05-17 16:29:03,124 [MainThread  ] [INFO ]  Processing res.10343.txt.
# 2019-05-17 16:29:03,130 [MainThread  ] [INFO ]  Processing res.10344.txt.
# 2019-05-17 16:29:03,135 [MainThread  ] [INFO ]  Processing res.10345.txt.
# 2019-05-17 16:29:03,141 [MainThread  ] [INFO ]  Processing res.10346.txt.
# 2019-05-17 16:29:03,147 [MainThread  ] [INFO ]  Processing res.10347.txt.
# 2019-05-17 16:29:03,153 [MainThread  ] [INFO ]  Processing res.10348.txt.
# 2019-05-17 16:29:03,158 [MainThread  ] [INFO ]  Processing res.10349.txt.
# 2019-05-17 16:29:03,164 [MainThread  ] [INFO ]  Processing res.1035.txt.
# 2019-05-17 16:29:03,173 [MainThread  ] [INFO ]  Processing res.10350.txt.
# 2019-05-17 16:29:03,179 [MainThread  ] [INFO ]  Processing res.10351.txt.
# 2019-05-17 16:29:03,185 [MainThread  ] [INFO ]  Processing res.10352.txt.
# 2019-05-17 16:29:03,190 [MainThread  ] [INFO ]  Processing res.10353.txt.
# 2019-05-17 16:29:03,196 [MainThread  ] [INFO ]  Processing res.10354.txt.
# 2019-05-17 16:29:03,201 [MainThread  ] [INFO ]  Processing res.10355.txt.
# 2019-05-17 16:29:03,208 [MainThread  ] [INFO ]  Processing res.10356.txt.
# 2019-05-17 16:29:03,213 [MainThread  ] [INFO ]  Processing res.10357.txt.
# 2019-05-17 16:29:03,219 [MainThread  ] [INFO ]  Processing res.10358.txt.
# 2019-05-17 16:29:03,224 [MainThread  ] [INFO ]  Processing res.10359.txt.
# 2019-05-17 16:29:03,231 [MainThread  ] [INFO ]  Processing res.1036.txt.
# 2019-05-17 16:29:03,238 [MainThread  ] [INFO ]  Processing res.10360.txt.
# 2019-05-17 16:29:03,244 [MainThread  ] [INFO ]  Processing res.10361.txt.
# 2019-05-17 16:29:03,249 [MainThread  ] [INFO ]  Processing res.10362.txt.
# 2019-05-17 16:29:03,255 [MainThread  ] [INFO ]  Processing res.10363.txt.
# 2019-05-17 16:29:03,260 [MainThread  ] [INFO ]  Processing res.10364.txt.
# 2019-05-17 16:29:03,266 [MainThread  ] [INFO ]  Processing res.10365.txt.
# 2019-05-17 16:29:03,272 [MainThread  ] [INFO ]  Processing res.10366.txt.
# 2019-05-17 16:29:03,277 [MainThread  ] [INFO ]  Processing res.10367.txt.
# 2019-05-17 16:29:03,283 [MainThread  ] [INFO ]  Processing res.10368.txt.
# 2019-05-17 16:29:03,289 [MainThread  ] [INFO ]  Processing res.10369.txt.
# 2019-05-17 16:29:03,294 [MainThread  ] [INFO ]  Processing res.1037.txt.
# 2019-05-17 16:29:03,303 [MainThread  ] [INFO ]  Processing res.10370.txt.
# 2019-05-17 16:29:03,309 [MainThread  ] [INFO ]  Processing res.10371.txt.
# 2019-05-17 16:29:03,315 [MainThread  ] [INFO ]  Processing res.10372.txt.
# 2019-05-17 16:29:03,321 [MainThread  ] [INFO ]  Processing res.10373.txt.
# 2019-05-17 16:29:03,327 [MainThread  ] [INFO ]  Processing res.10374.txt.
# 2019-05-17 16:29:03,332 [MainThread  ] [INFO ]  Processing res.10375.txt.
# 2019-05-17 16:29:03,338 [MainThread  ] [INFO ]  Processing res.10376.txt.
# 2019-05-17 16:29:03,344 [MainThread  ] [INFO ]  Processing res.10377.txt.
# 2019-05-17 16:29:03,349 [MainThread  ] [INFO ]  Processing res.10378.txt.
# 2019-05-17 16:29:03,354 [MainThread  ] [INFO ]  Processing res.10379.txt.
# 2019-05-17 16:29:03,360 [MainThread  ] [INFO ]  Processing res.1038.txt.
# 2019-05-17 16:29:03,368 [MainThread  ] [INFO ]  Processing res.10380.txt.
# 2019-05-17 16:29:03,374 [MainThread  ] [INFO ]  Processing res.10381.txt.
# 2019-05-17 16:29:03,380 [MainThread  ] [INFO ]  Processing res.10382.txt.
# 2019-05-17 16:29:03,386 [MainThread  ] [INFO ]  Processing res.10383.txt.
# 2019-05-17 16:29:03,391 [MainThread  ] [INFO ]  Processing res.10384.txt.
# 2019-05-17 16:29:03,397 [MainThread  ] [INFO ]  Processing res.10385.txt.
# 2019-05-17 16:29:03,402 [MainThread  ] [INFO ]  Processing res.10386.txt.
# 2019-05-17 16:29:03,408 [MainThread  ] [INFO ]  Processing res.10387.txt.
# 2019-05-17 16:29:03,414 [MainThread  ] [INFO ]  Processing res.10388.txt.
# 2019-05-17 16:29:03,420 [MainThread  ] [INFO ]  Processing res.10389.txt.
# 2019-05-17 16:29:03,427 [MainThread  ] [INFO ]  Processing res.1039.txt.
# 2019-05-17 16:29:03,434 [MainThread  ] [INFO ]  Processing res.10390.txt.
# 2019-05-17 16:29:03,440 [MainThread  ] [INFO ]  Processing res.10391.txt.
# 2019-05-17 16:29:03,448 [MainThread  ] [INFO ]  Processing res.10392.txt.
# 2019-05-17 16:29:03,454 [MainThread  ] [INFO ]  Processing res.10393.txt.
# 2019-05-17 16:29:03,459 [MainThread  ] [INFO ]  Processing res.10394.txt.
# 2019-05-17 16:29:03,465 [MainThread  ] [INFO ]  Processing res.10395.txt.
# 2019-05-17 16:29:03,472 [MainThread  ] [INFO ]  Processing res.10396.txt.
# 2019-05-17 16:29:03,478 [MainThread  ] [INFO ]  Processing res.10397.txt.
# 2019-05-17 16:29:03,483 [MainThread  ] [INFO ]  Processing res.10398.txt.
# 2019-05-17 16:29:03,490 [MainThread  ] [INFO ]  Processing res.10399.txt.
# 2019-05-17 16:29:03,495 [MainThread  ] [INFO ]  Processing res.104.txt.
# 2019-05-17 16:29:03,503 [MainThread  ] [INFO ]  Processing res.1040.txt.
# 2019-05-17 16:29:03,510 [MainThread  ] [INFO ]  Processing res.10400.txt.
# 2019-05-17 16:29:03,517 [MainThread  ] [INFO ]  Processing res.10401.txt.
# 2019-05-17 16:29:03,527 [MainThread  ] [INFO ]  Processing res.10402.txt.
# 2019-05-17 16:29:03,533 [MainThread  ] [INFO ]  Processing res.10403.txt.
# 2019-05-17 16:29:03,538 [MainThread  ] [INFO ]  Processing res.10404.txt.
# 2019-05-17 16:29:03,544 [MainThread  ] [INFO ]  Processing res.10405.txt.
# 2019-05-17 16:29:03,550 [MainThread  ] [INFO ]  Processing res.10406.txt.
# 2019-05-17 16:29:03,556 [MainThread  ] [INFO ]  Processing res.10407.txt.
# 2019-05-17 16:29:03,561 [MainThread  ] [INFO ]  Processing res.10408.txt.
# 2019-05-17 16:29:03,569 [MainThread  ] [INFO ]  Processing res.10409.txt.
# 2019-05-17 16:29:03,574 [MainThread  ] [INFO ]  Processing res.1041.txt.
# 2019-05-17 16:29:03,583 [MainThread  ] [INFO ]  Processing res.10410.txt.
# 2019-05-17 16:29:03,589 [MainThread  ] [INFO ]  Processing res.10411.txt.
# 2019-05-17 16:29:03,594 [MainThread  ] [INFO ]  Processing res.10412.txt.
# 2019-05-17 16:29:03,600 [MainThread  ] [INFO ]  Processing res.10413.txt.
# 2019-05-17 16:29:03,606 [MainThread  ] [INFO ]  Processing res.10414.txt.
# 2019-05-17 16:29:03,611 [MainThread  ] [INFO ]  Processing res.10415.txt.
# 2019-05-17 16:29:03,616 [MainThread  ] [INFO ]  Processing res.10416.txt.
# 2019-05-17 16:29:03,622 [MainThread  ] [INFO ]  Processing res.10417.txt.
# 2019-05-17 16:29:03,627 [MainThread  ] [INFO ]  Processing res.10418.txt.
# 2019-05-17 16:29:03,633 [MainThread  ] [INFO ]  Processing res.10419.txt.
# 2019-05-17 16:29:03,639 [MainThread  ] [INFO ]  Processing res.1042.txt.
# 2019-05-17 16:29:03,647 [MainThread  ] [INFO ]  Processing res.10420.txt.
# 2019-05-17 16:29:03,653 [MainThread  ] [INFO ]  Processing res.10421.txt.
# 2019-05-17 16:29:03,659 [MainThread  ] [INFO ]  Processing res.10422.txt.
# 2019-05-17 16:29:03,665 [MainThread  ] [INFO ]  Processing res.10423.txt.
# 2019-05-17 16:29:03,670 [MainThread  ] [INFO ]  Processing res.10424.txt.
# 2019-05-17 16:29:03,677 [MainThread  ] [INFO ]  Processing res.10425.txt.
# 2019-05-17 16:29:03,682 [MainThread  ] [INFO ]  Processing res.10426.txt.
# 2019-05-17 16:29:03,688 [MainThread  ] [INFO ]  Processing res.10427.txt.
# 2019-05-17 16:29:03,693 [MainThread  ] [INFO ]  Processing res.10428.txt.
# 2019-05-17 16:29:03,699 [MainThread  ] [INFO ]  Processing res.10429.txt.
# 2019-05-17 16:29:03,705 [MainThread  ] [INFO ]  Processing res.1043.txt.
# 2019-05-17 16:29:03,712 [MainThread  ] [INFO ]  Processing res.10430.txt.
# 2019-05-17 16:29:03,718 [MainThread  ] [INFO ]  Processing res.10431.txt.
# 2019-05-17 16:29:03,724 [MainThread  ] [INFO ]  Processing res.10432.txt.
# 2019-05-17 16:29:03,729 [MainThread  ] [INFO ]  Processing res.10433.txt.
# 2019-05-17 16:29:03,735 [MainThread  ] [INFO ]  Processing res.10434.txt.
# 2019-05-17 16:29:03,740 [MainThread  ] [INFO ]  Processing res.10435.txt.
# 2019-05-17 16:29:03,746 [MainThread  ] [INFO ]  Processing res.10436.txt.
# 2019-05-17 16:29:03,752 [MainThread  ] [INFO ]  Processing res.10437.txt.
# 2019-05-17 16:29:03,757 [MainThread  ] [INFO ]  Processing res.10438.txt.
# 2019-05-17 16:29:03,763 [MainThread  ] [INFO ]  Processing res.10439.txt.
# 2019-05-17 16:29:03,769 [MainThread  ] [INFO ]  Processing res.1044.txt.
# 2019-05-17 16:29:03,776 [MainThread  ] [INFO ]  Processing res.10440.txt.
# 2019-05-17 16:29:03,782 [MainThread  ] [INFO ]  Processing res.10441.txt.
# 2019-05-17 16:29:03,788 [MainThread  ] [INFO ]  Processing res.10442.txt.
# 2019-05-17 16:29:03,793 [MainThread  ] [INFO ]  Processing res.10443.txt.
# 2019-05-17 16:29:03,799 [MainThread  ] [INFO ]  Processing res.10444.txt.
# 2019-05-17 16:29:03,804 [MainThread  ] [INFO ]  Processing res.10445.txt.
# 2019-05-17 16:29:03,810 [MainThread  ] [INFO ]  Processing res.10446.txt.
# 2019-05-17 16:29:03,815 [MainThread  ] [INFO ]  Processing res.10447.txt.
# 2019-05-17 16:29:03,821 [MainThread  ] [INFO ]  Processing res.10448.txt.
# 2019-05-17 16:29:03,827 [MainThread  ] [INFO ]  Processing res.10449.txt.
# 2019-05-17 16:29:03,833 [MainThread  ] [INFO ]  Processing res.1045.txt.
# 2019-05-17 16:29:03,841 [MainThread  ] [INFO ]  Processing res.10450.txt.
# 2019-05-17 16:29:03,847 [MainThread  ] [INFO ]  Processing res.10451.txt.
# 2019-05-17 16:29:03,853 [MainThread  ] [INFO ]  Processing res.10452.txt.
# 2019-05-17 16:29:03,860 [MainThread  ] [INFO ]  Processing res.10453.txt.
# 2019-05-17 16:29:03,865 [MainThread  ] [INFO ]  Processing res.10454.txt.
# 2019-05-17 16:29:03,871 [MainThread  ] [INFO ]  Processing res.10455.txt.
# 2019-05-17 16:29:03,877 [MainThread  ] [INFO ]  Processing res.10456.txt.
# 2019-05-17 16:29:03,883 [MainThread  ] [INFO ]  Processing res.10457.txt.
# 2019-05-17 16:29:03,890 [MainThread  ] [INFO ]  Processing res.10458.txt.
# 2019-05-17 16:29:03,896 [MainThread  ] [INFO ]  Processing res.10459.txt.
# 2019-05-17 16:29:03,902 [MainThread  ] [INFO ]  Processing res.1046.txt.
# 2019-05-17 16:29:03,909 [MainThread  ] [INFO ]  Processing res.10460.txt.
# 2019-05-17 16:29:03,914 [MainThread  ] [INFO ]  Processing res.10461.txt.
# 2019-05-17 16:29:03,920 [MainThread  ] [INFO ]  Processing res.10462.txt.
# 2019-05-17 16:29:03,926 [MainThread  ] [INFO ]  Processing res.10463.txt.
# 2019-05-17 16:29:03,932 [MainThread  ] [INFO ]  Processing res.10464.txt.
# 2019-05-17 16:29:03,938 [MainThread  ] [INFO ]  Processing res.10465.txt.
# 2019-05-17 16:29:03,943 [MainThread  ] [INFO ]  Processing res.10466.txt.
# 2019-05-17 16:29:03,949 [MainThread  ] [INFO ]  Processing res.10467.txt.
# 2019-05-17 16:29:03,955 [MainThread  ] [INFO ]  Processing res.10468.txt.
# 2019-05-17 16:29:03,961 [MainThread  ] [INFO ]  Processing res.10469.txt.
# 2019-05-17 16:29:03,966 [MainThread  ] [INFO ]  Processing res.1047.txt.
# 2019-05-17 16:29:03,974 [MainThread  ] [INFO ]  Processing res.10470.txt.
# 2019-05-17 16:29:03,980 [MainThread  ] [INFO ]  Processing res.10471.txt.
# 2019-05-17 16:29:03,986 [MainThread  ] [INFO ]  Processing res.10472.txt.
# 2019-05-17 16:29:03,992 [MainThread  ] [INFO ]  Processing res.10473.txt.
# 2019-05-17 16:29:03,997 [MainThread  ] [INFO ]  Processing res.10474.txt.
# 2019-05-17 16:29:04,003 [MainThread  ] [INFO ]  Processing res.10475.txt.
# 2019-05-17 16:29:04,008 [MainThread  ] [INFO ]  Processing res.10476.txt.
# 2019-05-17 16:29:04,016 [MainThread  ] [INFO ]  Processing res.10477.txt.
# 2019-05-17 16:29:04,021 [MainThread  ] [INFO ]  Processing res.10478.txt.
# 2019-05-17 16:29:04,026 [MainThread  ] [INFO ]  Processing res.10479.txt.
# 2019-05-17 16:29:04,032 [MainThread  ] [INFO ]  Processing res.1048.txt.
# 2019-05-17 16:29:04,040 [MainThread  ] [INFO ]  Processing res.10480.txt.
# 2019-05-17 16:29:04,046 [MainThread  ] [INFO ]  Processing res.10481.txt.
# 2019-05-17 16:29:04,052 [MainThread  ] [INFO ]  Processing res.10482.txt.
# 2019-05-17 16:29:04,057 [MainThread  ] [INFO ]  Processing res.10483.txt.
# 2019-05-17 16:29:04,063 [MainThread  ] [INFO ]  Processing res.10484.txt.
# 2019-05-17 16:29:04,070 [MainThread  ] [INFO ]  Processing res.10485.txt.
# 2019-05-17 16:29:04,075 [MainThread  ] [INFO ]  Processing res.10486.txt.
# 2019-05-17 16:29:04,081 [MainThread  ] [INFO ]  Processing res.10487.txt.
# 2019-05-17 16:29:04,088 [MainThread  ] [INFO ]  Processing res.10488.txt.
# 2019-05-17 16:29:04,093 [MainThread  ] [INFO ]  Processing res.10489.txt.
# 2019-05-17 16:29:04,099 [MainThread  ] [INFO ]  Processing res.1049.txt.
# 2019-05-17 16:29:04,106 [MainThread  ] [INFO ]  Processing res.10490.txt.
# 2019-05-17 16:29:04,112 [MainThread  ] [INFO ]  Processing res.10491.txt.
# 2019-05-17 16:29:04,117 [MainThread  ] [INFO ]  Processing res.10492.txt.
# 2019-05-17 16:29:04,122 [MainThread  ] [INFO ]  Processing res.10493.txt.
# 2019-05-17 16:29:04,136 [MainThread  ] [INFO ]  Processing res.10494.txt.
# 2019-05-17 16:29:04,142 [MainThread  ] [INFO ]  Processing res.10495.txt.
# 2019-05-17 16:29:04,147 [MainThread  ] [INFO ]  Processing res.10496.txt.
# 2019-05-17 16:29:04,153 [MainThread  ] [INFO ]  Processing res.10497.txt.
# 2019-05-17 16:29:04,159 [MainThread  ] [INFO ]  Processing res.10498.txt.
# 2019-05-17 16:29:04,164 [MainThread  ] [INFO ]  Processing res.10499.txt.
# 2019-05-17 16:29:04,170 [MainThread  ] [INFO ]  Processing res.105.txt.
# 2019-05-17 16:29:04,178 [MainThread  ] [INFO ]  Processing res.1050.txt.
# 2019-05-17 16:29:04,186 [MainThread  ] [INFO ]  Processing res.10500.txt.
# 2019-05-17 16:29:04,192 [MainThread  ] [INFO ]  Processing res.10501.txt.
# 2019-05-17 16:29:04,199 [MainThread  ] [INFO ]  Processing res.10502.txt.
# 2019-05-17 16:29:04,205 [MainThread  ] [INFO ]  Processing res.10503.txt.
# 2019-05-17 16:29:04,210 [MainThread  ] [INFO ]  Processing res.10504.txt.
# 2019-05-17 16:29:04,216 [MainThread  ] [INFO ]  Processing res.10505.txt.
# 2019-05-17 16:29:04,222 [MainThread  ] [INFO ]  Processing res.10506.txt.
# 2019-05-17 16:29:04,227 [MainThread  ] [INFO ]  Processing res.10507.txt.
# 2019-05-17 16:29:04,232 [MainThread  ] [INFO ]  Processing res.10508.txt.
# 2019-05-17 16:29:04,237 [MainThread  ] [INFO ]  Processing res.10509.txt.
# 2019-05-17 16:29:04,243 [MainThread  ] [INFO ]  Processing res.1051.txt.
# 2019-05-17 16:29:04,250 [MainThread  ] [INFO ]  Processing res.10510.txt.
# 2019-05-17 16:29:04,256 [MainThread  ] [INFO ]  Processing res.10511.txt.
# 2019-05-17 16:29:04,261 [MainThread  ] [INFO ]  Processing res.10512.txt.
# 2019-05-17 16:29:04,267 [MainThread  ] [INFO ]  Processing res.10513.txt.
# 2019-05-17 16:29:04,273 [MainThread  ] [INFO ]  Processing res.10514.txt.
# 2019-05-17 16:29:04,278 [MainThread  ] [INFO ]  Processing res.10515.txt.
# 2019-05-17 16:29:04,284 [MainThread  ] [INFO ]  Processing res.10516.txt.
# 2019-05-17 16:29:04,289 [MainThread  ] [INFO ]  Processing res.10517.txt.
# 2019-05-17 16:29:04,295 [MainThread  ] [INFO ]  Processing res.10518.txt.
# 2019-05-17 16:29:04,300 [MainThread  ] [INFO ]  Processing res.10519.txt.
# 2019-05-17 16:29:04,306 [MainThread  ] [INFO ]  Processing res.1052.txt.
# 2019-05-17 16:29:04,314 [MainThread  ] [INFO ]  Processing res.10520.txt.
# 2019-05-17 16:29:04,319 [MainThread  ] [INFO ]  Processing res.10521.txt.
# 2019-05-17 16:29:04,325 [MainThread  ] [INFO ]  Processing res.10522.txt.
# 2019-05-17 16:29:04,331 [MainThread  ] [INFO ]  Processing res.10523.txt.
# 2019-05-17 16:29:04,336 [MainThread  ] [INFO ]  Processing res.10524.txt.
# 2019-05-17 16:29:04,342 [MainThread  ] [INFO ]  Processing res.10525.txt.
# 2019-05-17 16:29:04,348 [MainThread  ] [INFO ]  Processing res.10526.txt.
# 2019-05-17 16:29:04,354 [MainThread  ] [INFO ]  Processing res.10527.txt.
# 2019-05-17 16:29:04,360 [MainThread  ] [INFO ]  Processing res.10528.txt.
# 2019-05-17 16:29:04,365 [MainThread  ] [INFO ]  Processing res.10529.txt.
# 2019-05-17 16:29:04,371 [MainThread  ] [INFO ]  Processing res.1053.txt.
# 2019-05-17 16:29:04,378 [MainThread  ] [INFO ]  Processing res.10530.txt.
# 2019-05-17 16:29:04,384 [MainThread  ] [INFO ]  Processing res.10531.txt.
# 2019-05-17 16:29:04,390 [MainThread  ] [INFO ]  Processing res.10532.txt.
# 2019-05-17 16:29:04,395 [MainThread  ] [INFO ]  Processing res.10533.txt.
# 2019-05-17 16:29:04,401 [MainThread  ] [INFO ]  Processing res.10534.txt.
# 2019-05-17 16:29:04,407 [MainThread  ] [INFO ]  Processing res.10535.txt.
# 2019-05-17 16:29:04,412 [MainThread  ] [INFO ]  Processing res.10536.txt.
# 2019-05-17 16:29:04,419 [MainThread  ] [INFO ]  Processing res.10537.txt.
# 2019-05-17 16:29:04,425 [MainThread  ] [INFO ]  Processing res.10538.txt.
# 2019-05-17 16:29:04,430 [MainThread  ] [INFO ]  Processing res.10539.txt.
# 2019-05-17 16:29:04,436 [MainThread  ] [INFO ]  Processing res.1054.txt.
# 2019-05-17 16:29:04,444 [MainThread  ] [INFO ]  Processing res.10540.txt.
# 2019-05-17 16:29:04,450 [MainThread  ] [INFO ]  Processing res.10541.txt.
# 2019-05-17 16:29:04,456 [MainThread  ] [INFO ]  Processing res.10542.txt.
# 2019-05-17 16:29:04,462 [MainThread  ] [INFO ]  Processing res.10543.txt.
# 2019-05-17 16:29:04,467 [MainThread  ] [INFO ]  Processing res.10544.txt.
# 2019-05-17 16:29:04,474 [MainThread  ] [INFO ]  Processing res.10545.txt.
# 2019-05-17 16:29:04,480 [MainThread  ] [INFO ]  Processing res.10546.txt.
# 2019-05-17 16:29:04,486 [MainThread  ] [INFO ]  Processing res.10547.txt.
# 2019-05-17 16:29:04,491 [MainThread  ] [INFO ]  Processing res.10548.txt.
# 2019-05-17 16:29:04,497 [MainThread  ] [INFO ]  Processing res.10549.txt.
# 2019-05-17 16:29:04,503 [MainThread  ] [INFO ]  Processing res.1055.txt.
# 2019-05-17 16:29:04,511 [MainThread  ] [INFO ]  Processing res.10550.txt.
# 2019-05-17 16:29:04,516 [MainThread  ] [INFO ]  Processing res.10551.txt.
# 2019-05-17 16:29:04,522 [MainThread  ] [INFO ]  Processing res.10552.txt.
# 2019-05-17 16:29:04,528 [MainThread  ] [INFO ]  Processing res.10553.txt.
# 2019-05-17 16:29:04,534 [MainThread  ] [INFO ]  Processing res.10554.txt.
# 2019-05-17 16:29:04,539 [MainThread  ] [INFO ]  Processing res.10555.txt.
# 2019-05-17 16:29:04,545 [MainThread  ] [INFO ]  Processing res.10556.txt.
# 2019-05-17 16:29:04,552 [MainThread  ] [INFO ]  Processing res.10557.txt.
# 2019-05-17 16:29:04,557 [MainThread  ] [INFO ]  Processing res.10558.txt.
# 2019-05-17 16:29:04,563 [MainThread  ] [INFO ]  Processing res.10559.txt.
# 2019-05-17 16:29:04,568 [MainThread  ] [INFO ]  Processing res.1056.txt.
# 2019-05-17 16:29:04,576 [MainThread  ] [INFO ]  Processing res.10560.txt.
# 2019-05-17 16:29:04,582 [MainThread  ] [INFO ]  Processing res.10561.txt.
# 2019-05-17 16:29:04,587 [MainThread  ] [INFO ]  Processing res.10562.txt.
# 2019-05-17 16:29:04,593 [MainThread  ] [INFO ]  Processing res.10563.txt.
# 2019-05-17 16:29:04,598 [MainThread  ] [INFO ]  Processing res.10564.txt.
# 2019-05-17 16:29:04,603 [MainThread  ] [INFO ]  Processing res.10565.txt.
# 2019-05-17 16:29:04,609 [MainThread  ] [INFO ]  Processing res.10566.txt.
# 2019-05-17 16:29:04,613 [MainThread  ] [INFO ]  Processing res.10567.txt.
# 2019-05-17 16:29:04,619 [MainThread  ] [INFO ]  Processing res.10568.txt.
# 2019-05-17 16:29:04,625 [MainThread  ] [INFO ]  Processing res.10569.txt.
# 2019-05-17 16:29:04,630 [MainThread  ] [INFO ]  Processing res.1057.txt.
# 2019-05-17 16:29:04,638 [MainThread  ] [INFO ]  Processing res.10570.txt.
# 2019-05-17 16:29:04,644 [MainThread  ] [INFO ]  Processing res.10571.txt.
# 2019-05-17 16:29:04,650 [MainThread  ] [INFO ]  Processing res.10572.txt.
# 2019-05-17 16:29:04,656 [MainThread  ] [INFO ]  Processing res.10573.txt.
# 2019-05-17 16:29:04,662 [MainThread  ] [INFO ]  Processing res.10574.txt.
# 2019-05-17 16:29:04,667 [MainThread  ] [INFO ]  Processing res.10575.txt.
# 2019-05-17 16:29:04,675 [MainThread  ] [INFO ]  Processing res.10576.txt.
# ...
# 2019-05-17 16:31:22,418 [MainThread  ] [INFO ]  Processing ref.9832.txt.
# 2019-05-17 16:31:22,422 [MainThread  ] [INFO ]  Processing ref.9833.txt.
# 2019-05-17 16:31:22,428 [MainThread  ] [INFO ]  Processing ref.9834.txt.
# 2019-05-17 16:31:22,433 [MainThread  ] [INFO ]  Processing ref.9835.txt.
# 2019-05-17 16:31:22,439 [MainThread  ] [INFO ]  Processing ref.9836.txt.
# 2019-05-17 16:31:22,444 [MainThread  ] [INFO ]  Processing ref.9837.txt.
# 2019-05-17 16:31:22,449 [MainThread  ] [INFO ]  Processing ref.9838.txt.
# 2019-05-17 16:31:22,454 [MainThread  ] [INFO ]  Processing ref.9839.txt.
# 2019-05-17 16:31:22,458 [MainThread  ] [INFO ]  Processing ref.984.txt.
# 2019-05-17 16:31:22,466 [MainThread  ] [INFO ]  Processing ref.9840.txt.
# 2019-05-17 16:31:22,471 [MainThread  ] [INFO ]  Processing ref.9841.txt.
# 2019-05-17 16:31:22,477 [MainThread  ] [INFO ]  Processing ref.9842.txt.
# 2019-05-17 16:31:22,484 [MainThread  ] [INFO ]  Processing ref.9843.txt.
# 2019-05-17 16:31:22,490 [MainThread  ] [INFO ]  Processing ref.9844.txt.
# 2019-05-17 16:31:22,496 [MainThread  ] [INFO ]  Processing ref.9845.txt.
# 2019-05-17 16:31:22,501 [MainThread  ] [INFO ]  Processing ref.9846.txt.
# 2019-05-17 16:31:22,506 [MainThread  ] [INFO ]  Processing ref.9847.txt.
# 2019-05-17 16:31:22,511 [MainThread  ] [INFO ]  Processing ref.9848.txt.
# 2019-05-17 16:31:22,517 [MainThread  ] [INFO ]  Processing ref.9849.txt.
# 2019-05-17 16:31:22,523 [MainThread  ] [INFO ]  Processing ref.985.txt.
# 2019-05-17 16:31:22,530 [MainThread  ] [INFO ]  Processing ref.9850.txt.
# 2019-05-17 16:31:22,536 [MainThread  ] [INFO ]  Processing ref.9851.txt.
# 2019-05-17 16:31:22,544 [MainThread  ] [INFO ]  Processing ref.9852.txt.
# 2019-05-17 16:31:22,550 [MainThread  ] [INFO ]  Processing ref.9853.txt.
# 2019-05-17 16:31:22,556 [MainThread  ] [INFO ]  Processing ref.9854.txt.
# 2019-05-17 16:31:22,561 [MainThread  ] [INFO ]  Processing ref.9855.txt.
# 2019-05-17 16:31:22,568 [MainThread  ] [INFO ]  Processing ref.9856.txt.
# 2019-05-17 16:31:22,573 [MainThread  ] [INFO ]  Processing ref.9857.txt.
# 2019-05-17 16:31:22,579 [MainThread  ] [INFO ]  Processing ref.9858.txt.
# 2019-05-17 16:31:22,584 [MainThread  ] [INFO ]  Processing ref.9859.txt.
# 2019-05-17 16:31:22,589 [MainThread  ] [INFO ]  Processing ref.986.txt.
# 2019-05-17 16:31:22,596 [MainThread  ] [INFO ]  Processing ref.9860.txt.
# 2019-05-17 16:31:22,601 [MainThread  ] [INFO ]  Processing ref.9861.txt.
# 2019-05-17 16:31:22,607 [MainThread  ] [INFO ]  Processing ref.9862.txt.
# 2019-05-17 16:31:22,613 [MainThread  ] [INFO ]  Processing ref.9863.txt.
# 2019-05-17 16:31:22,618 [MainThread  ] [INFO ]  Processing ref.9864.txt.
# 2019-05-17 16:31:22,624 [MainThread  ] [INFO ]  Processing ref.9865.txt.
# 2019-05-17 16:31:22,629 [MainThread  ] [INFO ]  Processing ref.9866.txt.
# 2019-05-17 16:31:22,635 [MainThread  ] [INFO ]  Processing ref.9867.txt.
# 2019-05-17 16:31:22,640 [MainThread  ] [INFO ]  Processing ref.9868.txt.
# 2019-05-17 16:31:22,646 [MainThread  ] [INFO ]  Processing ref.9869.txt.
# 2019-05-17 16:31:22,651 [MainThread  ] [INFO ]  Processing ref.987.txt.
# 2019-05-17 16:31:22,660 [MainThread  ] [INFO ]  Processing ref.9870.txt.
# 2019-05-17 16:31:22,666 [MainThread  ] [INFO ]  Processing ref.9871.txt.
# 2019-05-17 16:31:22,672 [MainThread  ] [INFO ]  Processing ref.9872.txt.
# 2019-05-17 16:31:22,678 [MainThread  ] [INFO ]  Processing ref.9873.txt.
# 2019-05-17 16:31:22,683 [MainThread  ] [INFO ]  Processing ref.9874.txt.
# 2019-05-17 16:31:22,691 [MainThread  ] [INFO ]  Processing ref.9875.txt.
# 2019-05-17 16:31:22,696 [MainThread  ] [INFO ]  Processing ref.9876.txt.
# 2019-05-17 16:31:22,703 [MainThread  ] [INFO ]  Processing ref.9877.txt.
# 2019-05-17 16:31:22,709 [MainThread  ] [INFO ]  Processing ref.9878.txt.
# 2019-05-17 16:31:22,714 [MainThread  ] [INFO ]  Processing ref.9879.txt.
# 2019-05-17 16:31:22,720 [MainThread  ] [INFO ]  Processing ref.988.txt.
# 2019-05-17 16:31:22,729 [MainThread  ] [INFO ]  Processing ref.9880.txt.
# 2019-05-17 16:31:22,734 [MainThread  ] [INFO ]  Processing ref.9881.txt.
# 2019-05-17 16:31:22,740 [MainThread  ] [INFO ]  Processing ref.9882.txt.
# 2019-05-17 16:31:22,746 [MainThread  ] [INFO ]  Processing ref.9883.txt.
# 2019-05-17 16:31:22,753 [MainThread  ] [INFO ]  Processing ref.9884.txt.
# 2019-05-17 16:31:22,759 [MainThread  ] [INFO ]  Processing ref.9885.txt.
# 2019-05-17 16:31:22,765 [MainThread  ] [INFO ]  Processing ref.9886.txt.
# 2019-05-17 16:31:22,772 [MainThread  ] [INFO ]  Processing ref.9887.txt.
# 2019-05-17 16:31:22,779 [MainThread  ] [INFO ]  Processing ref.9888.txt.
# 2019-05-17 16:31:22,793 [MainThread  ] [INFO ]  Processing ref.9889.txt.
# 2019-05-17 16:31:22,800 [MainThread  ] [INFO ]  Processing ref.989.txt.
# 2019-05-17 16:31:22,808 [MainThread  ] [INFO ]  Processing ref.9890.txt.
# 2019-05-17 16:31:22,811 [MainThread  ] [INFO ]  Processing ref.9891.txt.
# 2019-05-17 16:31:22,819 [MainThread  ] [INFO ]  Processing ref.9892.txt.
# 2019-05-17 16:31:22,824 [MainThread  ] [INFO ]  Processing ref.9893.txt.
# 2019-05-17 16:31:22,830 [MainThread  ] [INFO ]  Processing ref.9894.txt.
# 2019-05-17 16:31:22,836 [MainThread  ] [INFO ]  Processing ref.9895.txt.
# 2019-05-17 16:31:22,842 [MainThread  ] [INFO ]  Processing ref.9896.txt.
# 2019-05-17 16:31:22,847 [MainThread  ] [INFO ]  Processing ref.9897.txt.
# 2019-05-17 16:31:22,853 [MainThread  ] [INFO ]  Processing ref.9898.txt.
# 2019-05-17 16:31:22,858 [MainThread  ] [INFO ]  Processing ref.9899.txt.
# 2019-05-17 16:31:22,864 [MainThread  ] [INFO ]  Processing ref.99.txt.
# 2019-05-17 16:31:22,872 [MainThread  ] [INFO ]  Processing ref.990.txt.
# 2019-05-17 16:31:22,875 [MainThread  ] [INFO ]  Processing ref.9900.txt.
# 2019-05-17 16:31:22,881 [MainThread  ] [INFO ]  Processing ref.9901.txt.
# 2019-05-17 16:31:22,885 [MainThread  ] [INFO ]  Processing ref.9902.txt.
# 2019-05-17 16:31:22,891 [MainThread  ] [INFO ]  Processing ref.9903.txt.
# 2019-05-17 16:31:22,896 [MainThread  ] [INFO ]  Processing ref.9904.txt.
# 2019-05-17 16:31:22,902 [MainThread  ] [INFO ]  Processing ref.9905.txt.
# 2019-05-17 16:31:22,908 [MainThread  ] [INFO ]  Processing ref.9906.txt.
# 2019-05-17 16:31:22,914 [MainThread  ] [INFO ]  Processing ref.9907.txt.
# 2019-05-17 16:31:22,919 [MainThread  ] [INFO ]  Processing ref.9908.txt.
# 2019-05-17 16:31:22,925 [MainThread  ] [INFO ]  Processing ref.9909.txt.
# 2019-05-17 16:31:22,931 [MainThread  ] [INFO ]  Processing ref.991.txt.
# 2019-05-17 16:31:22,938 [MainThread  ] [INFO ]  Processing ref.9910.txt.
# 2019-05-17 16:31:22,943 [MainThread  ] [INFO ]  Processing ref.9911.txt.
# 2019-05-17 16:31:22,948 [MainThread  ] [INFO ]  Processing ref.9912.txt.
# 2019-05-17 16:31:22,954 [MainThread  ] [INFO ]  Processing ref.9913.txt.
# 2019-05-17 16:31:22,960 [MainThread  ] [INFO ]  Processing ref.9914.txt.
# 2019-05-17 16:31:22,965 [MainThread  ] [INFO ]  Processing ref.9915.txt.
# 2019-05-17 16:31:22,970 [MainThread  ] [INFO ]  Processing ref.9916.txt.
# 2019-05-17 16:31:22,975 [MainThread  ] [INFO ]  Processing ref.9917.txt.
# 2019-05-17 16:31:22,980 [MainThread  ] [INFO ]  Processing ref.9918.txt.
# 2019-05-17 16:31:22,985 [MainThread  ] [INFO ]  Processing ref.9919.txt.
# 2019-05-17 16:31:22,990 [MainThread  ] [INFO ]  Processing ref.992.txt.
# 2019-05-17 16:31:22,997 [MainThread  ] [INFO ]  Processing ref.9920.txt.
# 2019-05-17 16:31:23,003 [MainThread  ] [INFO ]  Processing ref.9921.txt.
# 2019-05-17 16:31:23,009 [MainThread  ] [INFO ]  Processing ref.9922.txt.
# 2019-05-17 16:31:23,014 [MainThread  ] [INFO ]  Processing ref.9923.txt.
# 2019-05-17 16:31:23,019 [MainThread  ] [INFO ]  Processing ref.9924.txt.
# 2019-05-17 16:31:23,025 [MainThread  ] [INFO ]  Processing ref.9925.txt.
# 2019-05-17 16:31:23,032 [MainThread  ] [INFO ]  Processing ref.9926.txt.
# 2019-05-17 16:31:23,037 [MainThread  ] [INFO ]  Processing ref.9927.txt.
# 2019-05-17 16:31:23,043 [MainThread  ] [INFO ]  Processing ref.9928.txt.
# 2019-05-17 16:31:23,048 [MainThread  ] [INFO ]  Processing ref.9929.txt.
# 2019-05-17 16:31:23,053 [MainThread  ] [INFO ]  Processing ref.993.txt.
# 2019-05-17 16:31:23,063 [MainThread  ] [INFO ]  Processing ref.9930.txt.
# 2019-05-17 16:31:23,068 [MainThread  ] [INFO ]  Processing ref.9931.txt.
# 2019-05-17 16:31:23,073 [MainThread  ] [INFO ]  Processing ref.9932.txt.
# 2019-05-17 16:31:23,078 [MainThread  ] [INFO ]  Processing ref.9933.txt.
# 2019-05-17 16:31:23,083 [MainThread  ] [INFO ]  Processing ref.9934.txt.
# 2019-05-17 16:31:23,088 [MainThread  ] [INFO ]  Processing ref.9935.txt.
# 2019-05-17 16:31:23,094 [MainThread  ] [INFO ]  Processing ref.9936.txt.
# 2019-05-17 16:31:23,099 [MainThread  ] [INFO ]  Processing ref.9937.txt.
# 2019-05-17 16:31:23,104 [MainThread  ] [INFO ]  Processing ref.9938.txt.
# 2019-05-17 16:31:23,110 [MainThread  ] [INFO ]  Processing ref.9939.txt.
# 2019-05-17 16:31:23,115 [MainThread  ] [INFO ]  Processing ref.994.txt.
# 2019-05-17 16:31:23,120 [MainThread  ] [INFO ]  Processing ref.9940.txt.
# 2019-05-17 16:31:23,125 [MainThread  ] [INFO ]  Processing ref.9941.txt.
# 2019-05-17 16:31:23,131 [MainThread  ] [INFO ]  Processing ref.9942.txt.
# 2019-05-17 16:31:23,136 [MainThread  ] [INFO ]  Processing ref.9943.txt.
# 2019-05-17 16:31:23,141 [MainThread  ] [INFO ]  Processing ref.9944.txt.
# 2019-05-17 16:31:23,146 [MainThread  ] [INFO ]  Processing ref.9945.txt.
# 2019-05-17 16:31:23,151 [MainThread  ] [INFO ]  Processing ref.9946.txt.
# 2019-05-17 16:31:23,158 [MainThread  ] [INFO ]  Processing ref.9947.txt.
# 2019-05-17 16:31:23,163 [MainThread  ] [INFO ]  Processing ref.9948.txt.
# 2019-05-17 16:31:23,168 [MainThread  ] [INFO ]  Processing ref.9949.txt.
# 2019-05-17 16:31:23,174 [MainThread  ] [INFO ]  Processing ref.995.txt.
# 2019-05-17 16:31:23,180 [MainThread  ] [INFO ]  Processing ref.9950.txt.
# 2019-05-17 16:31:23,186 [MainThread  ] [INFO ]  Processing ref.9951.txt.
# 2019-05-17 16:31:23,192 [MainThread  ] [INFO ]  Processing ref.9952.txt.
# 2019-05-17 16:31:23,197 [MainThread  ] [INFO ]  Processing ref.9953.txt.
# 2019-05-17 16:31:23,202 [MainThread  ] [INFO ]  Processing ref.9954.txt.
# 2019-05-17 16:31:23,208 [MainThread  ] [INFO ]  Processing ref.9955.txt.
# 2019-05-17 16:31:23,213 [MainThread  ] [INFO ]  Processing ref.9956.txt.
# 2019-05-17 16:31:23,219 [MainThread  ] [INFO ]  Processing ref.9957.txt.
# 2019-05-17 16:31:23,224 [MainThread  ] [INFO ]  Processing ref.9958.txt.
# 2019-05-17 16:31:23,230 [MainThread  ] [INFO ]  Processing ref.9959.txt.
# 2019-05-17 16:31:23,235 [MainThread  ] [INFO ]  Processing ref.996.txt.
# 2019-05-17 16:31:23,242 [MainThread  ] [INFO ]  Processing ref.9960.txt.
# 2019-05-17 16:31:23,247 [MainThread  ] [INFO ]  Processing ref.9961.txt.
# 2019-05-17 16:31:23,252 [MainThread  ] [INFO ]  Processing ref.9962.txt.
# 2019-05-17 16:31:23,257 [MainThread  ] [INFO ]  Processing ref.9963.txt.
# 2019-05-17 16:31:23,262 [MainThread  ] [INFO ]  Processing ref.9964.txt.
# 2019-05-17 16:31:23,268 [MainThread  ] [INFO ]  Processing ref.9965.txt.
# 2019-05-17 16:31:23,273 [MainThread  ] [INFO ]  Processing ref.9966.txt.
# 2019-05-17 16:31:23,278 [MainThread  ] [INFO ]  Processing ref.9967.txt.
# 2019-05-17 16:31:23,283 [MainThread  ] [INFO ]  Processing ref.9968.txt.
# 2019-05-17 16:31:23,288 [MainThread  ] [INFO ]  Processing ref.9969.txt.
# 2019-05-17 16:31:23,294 [MainThread  ] [INFO ]  Processing ref.997.txt.
# 2019-05-17 16:31:23,300 [MainThread  ] [INFO ]  Processing ref.9970.txt.
# 2019-05-17 16:31:23,305 [MainThread  ] [INFO ]  Processing ref.9971.txt.
# 2019-05-17 16:31:23,311 [MainThread  ] [INFO ]  Processing ref.9972.txt.
# 2019-05-17 16:31:23,317 [MainThread  ] [INFO ]  Processing ref.9973.txt.
# 2019-05-17 16:31:23,322 [MainThread  ] [INFO ]  Processing ref.9974.txt.
# 2019-05-17 16:31:23,328 [MainThread  ] [INFO ]  Processing ref.9975.txt.
# 2019-05-17 16:31:23,333 [MainThread  ] [INFO ]  Processing ref.9976.txt.
# 2019-05-17 16:31:23,338 [MainThread  ] [INFO ]  Processing ref.9977.txt.
# 2019-05-17 16:31:23,344 [MainThread  ] [INFO ]  Processing ref.9978.txt.
# 2019-05-17 16:31:23,349 [MainThread  ] [INFO ]  Processing ref.9979.txt.
# 2019-05-17 16:31:23,355 [MainThread  ] [INFO ]  Processing ref.998.txt.
# 2019-05-17 16:31:23,363 [MainThread  ] [INFO ]  Processing ref.9980.txt.
# 2019-05-17 16:31:23,368 [MainThread  ] [INFO ]  Processing ref.9981.txt.
# 2019-05-17 16:31:23,373 [MainThread  ] [INFO ]  Processing ref.9982.txt.
# 2019-05-17 16:31:23,378 [MainThread  ] [INFO ]  Processing ref.9983.txt.
# 2019-05-17 16:31:23,383 [MainThread  ] [INFO ]  Processing ref.9984.txt.
# 2019-05-17 16:31:23,389 [MainThread  ] [INFO ]  Processing ref.9985.txt.
# 2019-05-17 16:31:23,398 [MainThread  ] [INFO ]  Processing ref.9986.txt.
# 2019-05-17 16:31:23,403 [MainThread  ] [INFO ]  Processing ref.9987.txt.
# 2019-05-17 16:31:23,408 [MainThread  ] [INFO ]  Processing ref.9988.txt.
# 2019-05-17 16:31:23,413 [MainThread  ] [INFO ]  Processing ref.9989.txt.
# 2019-05-17 16:31:23,419 [MainThread  ] [INFO ]  Processing ref.999.txt.
# 2019-05-17 16:31:23,425 [MainThread  ] [INFO ]  Processing ref.9990.txt.
# 2019-05-17 16:31:23,431 [MainThread  ] [INFO ]  Processing ref.9991.txt.
# 2019-05-17 16:31:23,436 [MainThread  ] [INFO ]  Processing ref.9992.txt.
# 2019-05-17 16:31:23,442 [MainThread  ] [INFO ]  Processing ref.9993.txt.
# 2019-05-17 16:31:23,447 [MainThread  ] [INFO ]  Processing ref.9994.txt.
# 2019-05-17 16:31:23,453 [MainThread  ] [INFO ]  Processing ref.9995.txt.
# 2019-05-17 16:31:23,458 [MainThread  ] [INFO ]  Processing ref.9996.txt.
# 2019-05-17 16:31:23,463 [MainThread  ] [INFO ]  Processing ref.9997.txt.
# 2019-05-17 16:31:23,468 [MainThread  ] [INFO ]  Processing ref.9998.txt.
# 2019-05-17 16:31:23,474 [MainThread  ] [INFO ]  Processing ref.9999.txt.
# 2019-05-17 16:31:23,479 [MainThread  ] [INFO ]  Saved processed files to C:\Users\Anatoly\AppData\Local\Temp\tmpnven7vn7\model.
# 2019-05-17 16:35:56,084 [MainThread  ] [INFO ]  Written ROUGE configuration to C:\Users\Anatoly\AppData\Local\Temp\tmpcrzz9zmb\rouge_conf.xml
# 2019-05-17 16:35:56,085 [MainThread  ] [INFO ]  Running ROUGE with command perl E:\NIR\pyrouge\tools\ROUGE-1.5.5\ROUGE-1.5.5.pl -e E:\NIR\pyrouge\tools\ROUGE-1.5.5\data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m C:\Users\Anatoly\AppData\Local\Temp\tmpcrzz9zmb\rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.53210 (95%-conf.int. 0.52954 - 0.53462)
# 1 ROUGE-1 Average_P: 0.24896 (95%-conf.int. 0.24718 - 0.25086)
# 1 ROUGE-1 Average_F: 0.33055 (95%-conf.int. 0.32862 - 0.33240)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.22798 (95%-conf.int. 0.22550 - 0.23055)
# 1 ROUGE-2 Average_P: 0.10601 (95%-conf.int. 0.10466 - 0.10741)
# 1 ROUGE-2 Average_F: 0.14091 (95%-conf.int. 0.13921 - 0.14260)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.12895 (95%-conf.int. 0.12661 - 0.13128)
# 1 ROUGE-3 Average_P: 0.06026 (95%-conf.int. 0.05904 - 0.06149)
# 1 ROUGE-3 Average_F: 0.07986 (95%-conf.int. 0.07834 - 0.08138)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.08503 (95%-conf.int. 0.08292 - 0.08710)
# 1 ROUGE-4 Average_P: 0.03994 (95%-conf.int. 0.03886 - 0.04106)
# 1 ROUGE-4 Average_F: 0.05277 (95%-conf.int. 0.05140 - 0.05416)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.49744 (95%-conf.int. 0.49494 - 0.50003)
# 1 ROUGE-L Average_P: 0.23228 (95%-conf.int. 0.23059 - 0.23396)
# 1 ROUGE-L Average_F: 0.30863 (95%-conf.int. 0.30678 - 0.31047)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.21420 (95%-conf.int. 0.21301 - 0.21552)
# 1 ROUGE-W-1.2 Average_P: 0.16635 (95%-conf.int. 0.16515 - 0.16756)
# 1 ROUGE-W-1.2 Average_F: 0.18101 (95%-conf.int. 0.17997 - 0.18201)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.26182 (95%-conf.int. 0.25930 - 0.26446)
# 1 ROUGE-S* Average_P: 0.06203 (95%-conf.int. 0.06108 - 0.06300)
# 1 ROUGE-S* Average_F: 0.09289 (95%-conf.int. 0.09169 - 0.09410)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.27307 (95%-conf.int. 0.27055 - 0.27570)
# 1 ROUGE-SU* Average_P: 0.06533 (95%-conf.int. 0.06436 - 0.06633)
# 1 ROUGE-SU* Average_F: 0.09783 (95%-conf.int. 0.09661 - 0.09905)

# %% [markdown]
# model.load_model("cov_loss2")

# %% [markdown]
# test_generate(model,test_data, beam_width=4, mod=1)

# %% [markdown]
# r = Rouge155()
# r.system_dir = 'E:/NIR/drag/res1'
# r.model_dir = 'E:/NIR/drag/refs1'
# r.system_filename_pattern = 'res.(\d+).txt'
# r.model_filename_pattern = 'ref.A.#ID#.txt'
#
# output = r.convert_and_evaluate()
# print(output)
# output_dict = r.output_to_dict(output)

# %%
0.10897
# Out:
# 0.10897
