# %%
from utils import *
from model3 import build_decoder_model

# %load_ext autoreload
# %autoreload 2
# Out:
# c:\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
vocab = Vocab("finished_files/vocab", VOCAB_SIZE)
# Out:
# Warning: incorrectly formatted line in vocabulary file: 0800В 555В 111 356
#
#
# Warning: incorrectly formatted line in vocabulary file: 1800В 333В 000 139
#
#
# Warning: incorrectly formatted line in vocabulary file: 2В 1/2 124
#
#
# Warning: incorrectly formatted line in vocabulary file: 3В 1/2 86
#
#
# max_size of vocab was specified as 50000; we now have 50000 words. Stopping reading.
# Finished constructing vocabulary of 50000 total words. Last word added: perisic

# %%
model = build_decoder_model(None)

# %%
#model = build_decoder_model(None)
model.load_model("full_retr")
torch.cuda.memory_allocated()
# Out:
# 271219712

# %%
class TestBatcher():
    
    def __init__(self, vocab, filename, max_article_len, max_target_len):
        generator = example_gen(filename)

        self.batches = []
        while True:
            
            try:
                article_text, abstract_text = next(generator)
                
                article_ids, unknown_words_list = article2ids(article_text, vocab)
                art_len = min(max_article_len, len(article_ids))
                article_ids = article_ids[:art_len]
                
                target = abstract2ids(abstract_text, vocab, unknown_words_list)
                tar_len = min(max_target_len, len(target))
                target.append(STOP_DECODING_ID)
                target = target[:tar_len]
                
                article_ids_unk = [i if i < VOCAB_SIZE else UNKNOWN_TOKEN_ID for i in article_ids]
                
                self.batches.append((np.array([article_ids]).T,np.array([article_ids_unk]).T, np.array(target), unknown_words_list))
                #print(article_text)
            except:
                break
        print(len(self.batches))
    
    def generator(self):
        for batch in self.batches:
            yield batch

# %%
test_data = TestBatcher(vocab, "finished_files/test.bin", 400, 80)
# Out:
# 11490

# %%
import codecs
from beam_search import run_beam_search
import os

def test_generate(model, data, beam_width, mod=0):  
    model.train(False)
    sbleu = 0
    with torch.autograd.set_grad_enabled(False):
        for i, (article_text_full, article_text, target, unk_words) in enumerate(data.generator()):
            #result = generate_summary(article_text, model, beam_width)
            
            '''X_batch = LongTensor(article_text)
            inputs = InputLayerState("input", True, X_batch)
            batch_size = X_batch.shape[1]
            symbols = LongTensor([[START_DECODING_ID]*batch_size])
            result = []
            model.eval_run_encoder(inputs, beam_search=False)
            for k in range(100):
                hidden = model.decode(symbols)
                symbols = hidden.argmax(-1)
                result.append(symbols.squeeze(0).item())
            '''
            X_batch, X_batch_full = LongTensor(article_text), LongTensor(article_text_full)
            inputs = [InputLayerState("input", True, X_batch), InputLayerState("input_full", True, X_batch_full)]
            result = run_beam_search(model, vocab, inputs, beam_width, 80)
            #print(result)
            #print(target)
            
            target = clean_sentence(target)
            result = clean_sentence(result)
            bleu = sentence_bleu([result], target, weights=(0.5, 0.5, 0., 0.))
            result = outputids2words(result, vocab, unk_words)
            target = outputids2words(target, vocab, unk_words)
            #print('{:.4f}'.format(bleu))
            sbleu += bleu
            '''if (bleu < 1e-3):
                print(result)
                print(0)
                print(target)'''
            #print(result.split())
            #print('target is \n')
            #print(target.split())
            if not os.access('refs' + str(mod), os.F_OK):
                os.mkdir('refs' + str(mod), 777)
            if not os.access('res' + str(mod), os.F_OK):
                os.mkdir('res' + str(mod), 777)
            with codecs.open('refs' + str(mod) + '/ref.' + str(i) +'.txt', 'w', encoding='utf8') as reference_file:
                sentences = target.split('.')
                for s in sentences:
                    reference_file.write(s.strip() + '.\n')
                
                
            with codecs.open('res' + str(mod) + '/res.' + str(i) + '.txt', 'w', encoding='utf8') as result_file:
                sentences = result.split('.')
                for s in sentences:
                    result_file.write(s.strip() + '.\n')
        print(sbleu/1000)

# %%
test_generate(model, test_data, beam_width=4)
# Out:
# c:\python36\lib\site-packages\nltk\translate\bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# c:\python36\lib\site-packages\nltk\translate\bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# c:\python36\lib\site-packages\nltk\translate\bleu_score.py:503: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 1.2760019220006562

# %%
from pyrouge import Rouge155

r = Rouge155()
r.system_dir = 'E:/NIR/drag/res0'
r.model_dir = 'E:/NIR/drag/refs0'
r.system_filename_pattern = 'res.(\d+).txt'
r.model_filename_pattern = 'ref.#ID#.txt'

output = r.convert_and_evaluate()
print(output)
output_dict = r.output_to_dict(output)
# Out:
# 2019-06-14 03:33:00,475 [MainThread  ] [INFO ]  Writing summaries.
# 2019-06-14 03:33:00,476 [MainThread  ] [INFO ]  Processing summaries. Saving system files to C:\Users\Anatoly\AppData\Local\Temp\tmp53rdyvxn\system and model files to C:\Users\Anatoly\AppData\Local\Temp\tmp53rdyvxn\model.
# 2019-06-14 03:33:00,477 [MainThread  ] [INFO ]  Processing files in E:/NIR/drag/res0.
# 2019-06-14 03:33:00,488 [MainThread  ] [INFO ]  Processing res.0.txt.
# 2019-06-14 03:33:00,494 [MainThread  ] [INFO ]  Processing res.1.txt.
# 2019-06-14 03:33:00,500 [MainThread  ] [INFO ]  Processing res.10.txt.
# 2019-06-14 03:33:00,506 [MainThread  ] [INFO ]  Processing res.100.txt.
# 2019-06-14 03:33:00,511 [MainThread  ] [INFO ]  Processing res.1000.txt.
# 2019-06-14 03:33:00,517 [MainThread  ] [INFO ]  Processing res.10000.txt.
# 2019-06-14 03:33:00,523 [MainThread  ] [INFO ]  Processing res.10001.txt.
# 2019-06-14 03:33:00,528 [MainThread  ] [INFO ]  Processing res.10002.txt.
# 2019-06-14 03:33:00,535 [MainThread  ] [INFO ]  Processing res.10003.txt.
# 2019-06-14 03:33:00,541 [MainThread  ] [INFO ]  Processing res.10004.txt.
# 2019-06-14 03:33:00,547 [MainThread  ] [INFO ]  Processing res.10005.txt.
# 2019-06-14 03:33:00,553 [MainThread  ] [INFO ]  Processing res.10006.txt.
# 2019-06-14 03:33:00,558 [MainThread  ] [INFO ]  Processing res.10007.txt.
# 2019-06-14 03:33:00,564 [MainThread  ] [INFO ]  Processing res.10008.txt.
# 2019-06-14 03:33:00,570 [MainThread  ] [INFO ]  Processing res.10009.txt.
# 2019-06-14 03:33:00,575 [MainThread  ] [INFO ]  Processing res.1001.txt.
# 2019-06-14 03:33:00,580 [MainThread  ] [INFO ]  Processing res.10010.txt.
# 2019-06-14 03:33:00,586 [MainThread  ] [INFO ]  Processing res.10011.txt.
# 2019-06-14 03:33:00,591 [MainThread  ] [INFO ]  Processing res.10012.txt.
# 2019-06-14 03:33:00,597 [MainThread  ] [INFO ]  Processing res.10013.txt.
# 2019-06-14 03:33:00,603 [MainThread  ] [INFO ]  Processing res.10014.txt.
# 2019-06-14 03:33:00,608 [MainThread  ] [INFO ]  Processing res.10015.txt.
# 2019-06-14 03:33:00,614 [MainThread  ] [INFO ]  Processing res.10016.txt.
# 2019-06-14 03:33:00,619 [MainThread  ] [INFO ]  Processing res.10017.txt.
# 2019-06-14 03:33:00,624 [MainThread  ] [INFO ]  Processing res.10018.txt.
# 2019-06-14 03:33:00,630 [MainThread  ] [INFO ]  Processing res.10019.txt.
# 2019-06-14 03:33:00,635 [MainThread  ] [INFO ]  Processing res.1002.txt.
# 2019-06-14 03:33:00,641 [MainThread  ] [INFO ]  Processing res.10020.txt.
# 2019-06-14 03:33:00,646 [MainThread  ] [INFO ]  Processing res.10021.txt.
# 2019-06-14 03:33:00,652 [MainThread  ] [INFO ]  Processing res.10022.txt.
# 2019-06-14 03:33:00,657 [MainThread  ] [INFO ]  Processing res.10023.txt.
# 2019-06-14 03:33:00,662 [MainThread  ] [INFO ]  Processing res.10024.txt.
# 2019-06-14 03:33:00,668 [MainThread  ] [INFO ]  Processing res.10025.txt.
# 2019-06-14 03:33:00,674 [MainThread  ] [INFO ]  Processing res.10026.txt.
# 2019-06-14 03:33:00,679 [MainThread  ] [INFO ]  Processing res.10027.txt.
# 2019-06-14 03:33:00,685 [MainThread  ] [INFO ]  Processing res.10028.txt.
# 2019-06-14 03:33:00,691 [MainThread  ] [INFO ]  Processing res.10029.txt.
# 2019-06-14 03:33:00,697 [MainThread  ] [INFO ]  Processing res.1003.txt.
# 2019-06-14 03:33:00,702 [MainThread  ] [INFO ]  Processing res.10030.txt.
# 2019-06-14 03:33:00,708 [MainThread  ] [INFO ]  Processing res.10031.txt.
# 2019-06-14 03:33:00,713 [MainThread  ] [INFO ]  Processing res.10032.txt.
# 2019-06-14 03:33:00,719 [MainThread  ] [INFO ]  Processing res.10033.txt.
# 2019-06-14 03:33:00,724 [MainThread  ] [INFO ]  Processing res.10034.txt.
# 2019-06-14 03:33:00,730 [MainThread  ] [INFO ]  Processing res.10035.txt.
# 2019-06-14 03:33:00,735 [MainThread  ] [INFO ]  Processing res.10036.txt.
# 2019-06-14 03:33:00,741 [MainThread  ] [INFO ]  Processing res.10037.txt.
# 2019-06-14 03:33:00,746 [MainThread  ] [INFO ]  Processing res.10038.txt.
# 2019-06-14 03:33:00,751 [MainThread  ] [INFO ]  Processing res.10039.txt.
# 2019-06-14 03:33:00,756 [MainThread  ] [INFO ]  Processing res.1004.txt.
# 2019-06-14 03:33:00,762 [MainThread  ] [INFO ]  Processing res.10040.txt.
# 2019-06-14 03:33:00,768 [MainThread  ] [INFO ]  Processing res.10041.txt.
# 2019-06-14 03:33:00,773 [MainThread  ] [INFO ]  Processing res.10042.txt.
# 2019-06-14 03:33:00,778 [MainThread  ] [INFO ]  Processing res.10043.txt.
# 2019-06-14 03:33:00,784 [MainThread  ] [INFO ]  Processing res.10044.txt.
# 2019-06-14 03:33:00,789 [MainThread  ] [INFO ]  Processing res.10045.txt.
# 2019-06-14 03:33:00,795 [MainThread  ] [INFO ]  Processing res.10046.txt.
# 2019-06-14 03:33:00,801 [MainThread  ] [INFO ]  Processing res.10047.txt.
# 2019-06-14 03:33:00,806 [MainThread  ] [INFO ]  Processing res.10048.txt.
# 2019-06-14 03:33:00,812 [MainThread  ] [INFO ]  Processing res.10049.txt.
# 2019-06-14 03:33:00,818 [MainThread  ] [INFO ]  Processing res.1005.txt.
# 2019-06-14 03:33:00,823 [MainThread  ] [INFO ]  Processing res.10050.txt.
# 2019-06-14 03:33:00,829 [MainThread  ] [INFO ]  Processing res.10051.txt.
# 2019-06-14 03:33:00,834 [MainThread  ] [INFO ]  Processing res.10052.txt.
# 2019-06-14 03:33:00,840 [MainThread  ] [INFO ]  Processing res.10053.txt.
# 2019-06-14 03:33:00,845 [MainThread  ] [INFO ]  Processing res.10054.txt.
# 2019-06-14 03:33:00,852 [MainThread  ] [INFO ]  Processing res.10055.txt.
# 2019-06-14 03:33:00,857 [MainThread  ] [INFO ]  Processing res.10056.txt.
# 2019-06-14 03:33:00,863 [MainThread  ] [INFO ]  Processing res.10057.txt.
# 2019-06-14 03:33:00,869 [MainThread  ] [INFO ]  Processing res.10058.txt.
# 2019-06-14 03:33:00,874 [MainThread  ] [INFO ]  Processing res.10059.txt.
# 2019-06-14 03:33:00,879 [MainThread  ] [INFO ]  Processing res.1006.txt.
# 2019-06-14 03:33:00,886 [MainThread  ] [INFO ]  Processing res.10060.txt.
# 2019-06-14 03:33:00,891 [MainThread  ] [INFO ]  Processing res.10061.txt.
# 2019-06-14 03:33:00,897 [MainThread  ] [INFO ]  Processing res.10062.txt.
# 2019-06-14 03:33:00,902 [MainThread  ] [INFO ]  Processing res.10063.txt.
# 2019-06-14 03:33:00,908 [MainThread  ] [INFO ]  Processing res.10064.txt.
# 2019-06-14 03:33:00,913 [MainThread  ] [INFO ]  Processing res.10065.txt.
# 2019-06-14 03:33:00,919 [MainThread  ] [INFO ]  Processing res.10066.txt.
# 2019-06-14 03:33:00,924 [MainThread  ] [INFO ]  Processing res.10067.txt.
# 2019-06-14 03:33:00,930 [MainThread  ] [INFO ]  Processing res.10068.txt.
# 2019-06-14 03:33:00,935 [MainThread  ] [INFO ]  Processing res.10069.txt.
# 2019-06-14 03:33:00,941 [MainThread  ] [INFO ]  Processing res.1007.txt.
# 2019-06-14 03:33:00,946 [MainThread  ] [INFO ]  Processing res.10070.txt.
# 2019-06-14 03:33:00,952 [MainThread  ] [INFO ]  Processing res.10071.txt.
# 2019-06-14 03:33:00,958 [MainThread  ] [INFO ]  Processing res.10072.txt.
# 2019-06-14 03:33:00,963 [MainThread  ] [INFO ]  Processing res.10073.txt.
# 2019-06-14 03:33:00,969 [MainThread  ] [INFO ]  Processing res.10074.txt.
# 2019-06-14 03:33:00,974 [MainThread  ] [INFO ]  Processing res.10075.txt.
# 2019-06-14 03:33:00,980 [MainThread  ] [INFO ]  Processing res.10076.txt.
# 2019-06-14 03:33:00,986 [MainThread  ] [INFO ]  Processing res.10077.txt.
# 2019-06-14 03:33:00,991 [MainThread  ] [INFO ]  Processing res.10078.txt.
# 2019-06-14 03:33:00,997 [MainThread  ] [INFO ]  Processing res.10079.txt.
# 2019-06-14 03:33:01,003 [MainThread  ] [INFO ]  Processing res.1008.txt.
# 2019-06-14 03:33:01,008 [MainThread  ] [INFO ]  Processing res.10080.txt.
# 2019-06-14 03:33:01,014 [MainThread  ] [INFO ]  Processing res.10081.txt.
# 2019-06-14 03:33:01,019 [MainThread  ] [INFO ]  Processing res.10082.txt.
# 2019-06-14 03:33:01,025 [MainThread  ] [INFO ]  Processing res.10083.txt.
# 2019-06-14 03:33:01,030 [MainThread  ] [INFO ]  Processing res.10084.txt.
# 2019-06-14 03:33:01,036 [MainThread  ] [INFO ]  Processing res.10085.txt.
# 2019-06-14 03:33:01,042 [MainThread  ] [INFO ]  Processing res.10086.txt.
# 2019-06-14 03:33:01,047 [MainThread  ] [INFO ]  Processing res.10087.txt.
# 2019-06-14 03:33:01,053 [MainThread  ] [INFO ]  Processing res.10088.txt.
# 2019-06-14 03:33:01,058 [MainThread  ] [INFO ]  Processing res.10089.txt.
# 2019-06-14 03:33:01,064 [MainThread  ] [INFO ]  Processing res.1009.txt.
# 2019-06-14 03:33:01,070 [MainThread  ] [INFO ]  Processing res.10090.txt.
# 2019-06-14 03:33:01,076 [MainThread  ] [INFO ]  Processing res.10091.txt.
# 2019-06-14 03:33:01,082 [MainThread  ] [INFO ]  Processing res.10092.txt.
# 2019-06-14 03:33:01,087 [MainThread  ] [INFO ]  Processing res.10093.txt.
# 2019-06-14 03:33:01,093 [MainThread  ] [INFO ]  Processing res.10094.txt.
# 2019-06-14 03:33:01,099 [MainThread  ] [INFO ]  Processing res.10095.txt.
# 2019-06-14 03:33:01,105 [MainThread  ] [INFO ]  Processing res.10096.txt.
# 2019-06-14 03:33:01,110 [MainThread  ] [INFO ]  Processing res.10097.txt.
# 2019-06-14 03:33:01,116 [MainThread  ] [INFO ]  Processing res.10098.txt.
# 2019-06-14 03:33:01,121 [MainThread  ] [INFO ]  Processing res.10099.txt.
# 2019-06-14 03:33:01,127 [MainThread  ] [INFO ]  Processing res.101.txt.
# 2019-06-14 03:33:01,132 [MainThread  ] [INFO ]  Processing res.1010.txt.
# 2019-06-14 03:33:01,138 [MainThread  ] [INFO ]  Processing res.10100.txt.
# 2019-06-14 03:33:01,143 [MainThread  ] [INFO ]  Processing res.10101.txt.
# 2019-06-14 03:33:01,149 [MainThread  ] [INFO ]  Processing res.10102.txt.
# 2019-06-14 03:33:01,155 [MainThread  ] [INFO ]  Processing res.10103.txt.
# 2019-06-14 03:33:01,161 [MainThread  ] [INFO ]  Processing res.10104.txt.
# 2019-06-14 03:33:01,166 [MainThread  ] [INFO ]  Processing res.10105.txt.
# 2019-06-14 03:33:01,172 [MainThread  ] [INFO ]  Processing res.10106.txt.
# 2019-06-14 03:33:01,178 [MainThread  ] [INFO ]  Processing res.10107.txt.
# 2019-06-14 03:33:01,188 [MainThread  ] [INFO ]  Processing res.10108.txt.
# 2019-06-14 03:33:01,193 [MainThread  ] [INFO ]  Processing res.10109.txt.
# 2019-06-14 03:33:01,199 [MainThread  ] [INFO ]  Processing res.1011.txt.
# 2019-06-14 03:33:01,204 [MainThread  ] [INFO ]  Processing res.10110.txt.
# 2019-06-14 03:33:01,210 [MainThread  ] [INFO ]  Processing res.10111.txt.
# 2019-06-14 03:33:01,216 [MainThread  ] [INFO ]  Processing res.10112.txt.
# 2019-06-14 03:33:01,221 [MainThread  ] [INFO ]  Processing res.10113.txt.
# 2019-06-14 03:33:01,226 [MainThread  ] [INFO ]  Processing res.10114.txt.
# 2019-06-14 03:33:01,232 [MainThread  ] [INFO ]  Processing res.10115.txt.
# 2019-06-14 03:33:01,238 [MainThread  ] [INFO ]  Processing res.10116.txt.
# 2019-06-14 03:33:01,243 [MainThread  ] [INFO ]  Processing res.10117.txt.
# 2019-06-14 03:33:01,249 [MainThread  ] [INFO ]  Processing res.10118.txt.
# 2019-06-14 03:33:01,254 [MainThread  ] [INFO ]  Processing res.10119.txt.
# 2019-06-14 03:33:01,260 [MainThread  ] [INFO ]  Processing res.1012.txt.
# 2019-06-14 03:33:01,265 [MainThread  ] [INFO ]  Processing res.10120.txt.
# 2019-06-14 03:33:01,271 [MainThread  ] [INFO ]  Processing res.10121.txt.
# 2019-06-14 03:33:01,277 [MainThread  ] [INFO ]  Processing res.10122.txt.
# 2019-06-14 03:33:01,283 [MainThread  ] [INFO ]  Processing res.10123.txt.
# 2019-06-14 03:33:01,288 [MainThread  ] [INFO ]  Processing res.10124.txt.
# 2019-06-14 03:33:01,293 [MainThread  ] [INFO ]  Processing res.10125.txt.
# 2019-06-14 03:33:01,299 [MainThread  ] [INFO ]  Processing res.10126.txt.
# 2019-06-14 03:33:01,305 [MainThread  ] [INFO ]  Processing res.10127.txt.
# 2019-06-14 03:33:01,310 [MainThread  ] [INFO ]  Processing res.10128.txt.
# 2019-06-14 03:33:01,316 [MainThread  ] [INFO ]  Processing res.10129.txt.
# 2019-06-14 03:33:01,322 [MainThread  ] [INFO ]  Processing res.1013.txt.
# 2019-06-14 03:33:01,327 [MainThread  ] [INFO ]  Processing res.10130.txt.
# 2019-06-14 03:33:01,333 [MainThread  ] [INFO ]  Processing res.10131.txt.
# 2019-06-14 03:33:01,339 [MainThread  ] [INFO ]  Processing res.10132.txt.
# 2019-06-14 03:33:01,345 [MainThread  ] [INFO ]  Processing res.10133.txt.
# 2019-06-14 03:33:01,351 [MainThread  ] [INFO ]  Processing res.10134.txt.
# 2019-06-14 03:33:01,357 [MainThread  ] [INFO ]  Processing res.10135.txt.
# 2019-06-14 03:33:01,362 [MainThread  ] [INFO ]  Processing res.10136.txt.
# 2019-06-14 03:33:01,368 [MainThread  ] [INFO ]  Processing res.10137.txt.
# 2019-06-14 03:33:01,374 [MainThread  ] [INFO ]  Processing res.10138.txt.
# 2019-06-14 03:33:01,379 [MainThread  ] [INFO ]  Processing res.10139.txt.
# 2019-06-14 03:33:01,385 [MainThread  ] [INFO ]  Processing res.1014.txt.
# 2019-06-14 03:33:01,391 [MainThread  ] [INFO ]  Processing res.10140.txt.
# 2019-06-14 03:33:01,406 [MainThread  ] [INFO ]  Processing res.10141.txt.
# 2019-06-14 03:33:01,412 [MainThread  ] [INFO ]  Processing res.10142.txt.
# 2019-06-14 03:33:01,417 [MainThread  ] [INFO ]  Processing res.10143.txt.
# 2019-06-14 03:33:01,423 [MainThread  ] [INFO ]  Processing res.10144.txt.
# 2019-06-14 03:33:01,428 [MainThread  ] [INFO ]  Processing res.10145.txt.
# 2019-06-14 03:33:01,434 [MainThread  ] [INFO ]  Processing res.10146.txt.
# 2019-06-14 03:33:01,439 [MainThread  ] [INFO ]  Processing res.10147.txt.
# 2019-06-14 03:33:01,445 [MainThread  ] [INFO ]  Processing res.10148.txt.
# 2019-06-14 03:33:01,450 [MainThread  ] [INFO ]  Processing res.10149.txt.
# 2019-06-14 03:33:01,456 [MainThread  ] [INFO ]  Processing res.1015.txt.
# 2019-06-14 03:33:01,461 [MainThread  ] [INFO ]  Processing res.10150.txt.
# 2019-06-14 03:33:01,467 [MainThread  ] [INFO ]  Processing res.10151.txt.
# 2019-06-14 03:33:01,473 [MainThread  ] [INFO ]  Processing res.10152.txt.
# 2019-06-14 03:33:01,478 [MainThread  ] [INFO ]  Processing res.10153.txt.
# 2019-06-14 03:33:01,484 [MainThread  ] [INFO ]  Processing res.10154.txt.
# 2019-06-14 03:33:01,495 [MainThread  ] [INFO ]  Processing res.10155.txt.
# 2019-06-14 03:33:01,501 [MainThread  ] [INFO ]  Processing res.10156.txt.
# 2019-06-14 03:33:01,506 [MainThread  ] [INFO ]  Processing res.10157.txt.
# 2019-06-14 03:33:01,511 [MainThread  ] [INFO ]  Processing res.10158.txt.
# 2019-06-14 03:33:01,517 [MainThread  ] [INFO ]  Processing res.10159.txt.
# 2019-06-14 03:33:01,523 [MainThread  ] [INFO ]  Processing res.1016.txt.
# 2019-06-14 03:33:01,528 [MainThread  ] [INFO ]  Processing res.10160.txt.
# 2019-06-14 03:33:01,534 [MainThread  ] [INFO ]  Processing res.10161.txt.
# 2019-06-14 03:33:01,539 [MainThread  ] [INFO ]  Processing res.10162.txt.
# 2019-06-14 03:33:01,545 [MainThread  ] [INFO ]  Processing res.10163.txt.
# 2019-06-14 03:33:01,551 [MainThread  ] [INFO ]  Processing res.10164.txt.
# 2019-06-14 03:33:01,557 [MainThread  ] [INFO ]  Processing res.10165.txt.
# 2019-06-14 03:33:01,562 [MainThread  ] [INFO ]  Processing res.10166.txt.
# 2019-06-14 03:33:01,568 [MainThread  ] [INFO ]  Processing res.10167.txt.
# 2019-06-14 03:33:01,574 [MainThread  ] [INFO ]  Processing res.10168.txt.
# 2019-06-14 03:33:01,579 [MainThread  ] [INFO ]  Processing res.10169.txt.
# 2019-06-14 03:33:01,585 [MainThread  ] [INFO ]  Processing res.1017.txt.
# 2019-06-14 03:33:01,591 [MainThread  ] [INFO ]  Processing res.10170.txt.
# 2019-06-14 03:33:01,596 [MainThread  ] [INFO ]  Processing res.10171.txt.
# 2019-06-14 03:33:01,602 [MainThread  ] [INFO ]  Processing res.10172.txt.
# 2019-06-14 03:33:01,608 [MainThread  ] [INFO ]  Processing res.10173.txt.
# 2019-06-14 03:33:01,613 [MainThread  ] [INFO ]  Processing res.10174.txt.
# 2019-06-14 03:33:01,619 [MainThread  ] [INFO ]  Processing res.10175.txt.
# 2019-06-14 03:33:01,624 [MainThread  ] [INFO ]  Processing res.10176.txt.
# 2019-06-14 03:33:01,630 [MainThread  ] [INFO ]  Processing res.10177.txt.
# 2019-06-14 03:33:01,635 [MainThread  ] [INFO ]  Processing res.10178.txt.
# 2019-06-14 03:33:01,641 [MainThread  ] [INFO ]  Processing res.10179.txt.
# 2019-06-14 03:33:01,646 [MainThread  ] [INFO ]  Processing res.1018.txt.
# 2019-06-14 03:33:01,653 [MainThread  ] [INFO ]  Processing res.10180.txt.
# 2019-06-14 03:33:01,658 [MainThread  ] [INFO ]  Processing res.10181.txt.
# 2019-06-14 03:33:01,664 [MainThread  ] [INFO ]  Processing res.10182.txt.
# 2019-06-14 03:33:01,669 [MainThread  ] [INFO ]  Processing res.10183.txt.
# 2019-06-14 03:33:01,675 [MainThread  ] [INFO ]  Processing res.10184.txt.
# 2019-06-14 03:33:01,680 [MainThread  ] [INFO ]  Processing res.10185.txt.
# 2019-06-14 03:33:01,686 [MainThread  ] [INFO ]  Processing res.10186.txt.
# 2019-06-14 03:33:01,692 [MainThread  ] [INFO ]  Processing res.10187.txt.
# 2019-06-14 03:33:01,697 [MainThread  ] [INFO ]  Processing res.10188.txt.
# 2019-06-14 03:33:01,703 [MainThread  ] [INFO ]  Processing res.10189.txt.
# 2019-06-14 03:33:01,709 [MainThread  ] [INFO ]  Processing res.1019.txt.
# 2019-06-14 03:33:01,714 [MainThread  ] [INFO ]  Processing res.10190.txt.
# 2019-06-14 03:33:01,720 [MainThread  ] [INFO ]  Processing res.10191.txt.
# 2019-06-14 03:33:01,725 [MainThread  ] [INFO ]  Processing res.10192.txt.
# 2019-06-14 03:33:01,731 [MainThread  ] [INFO ]  Processing res.10193.txt.
# 2019-06-14 03:33:01,737 [MainThread  ] [INFO ]  Processing res.10194.txt.
# 2019-06-14 03:33:01,742 [MainThread  ] [INFO ]  Processing res.10195.txt.
# 2019-06-14 03:33:01,748 [MainThread  ] [INFO ]  Processing res.10196.txt.
# 2019-06-14 03:33:01,754 [MainThread  ] [INFO ]  Processing res.10197.txt.
# 2019-06-14 03:33:01,759 [MainThread  ] [INFO ]  Processing res.10198.txt.
# 2019-06-14 03:33:01,765 [MainThread  ] [INFO ]  Processing res.10199.txt.
# 2019-06-14 03:33:01,770 [MainThread  ] [INFO ]  Processing res.102.txt.
# 2019-06-14 03:33:01,776 [MainThread  ] [INFO ]  Processing res.1020.txt.
# 2019-06-14 03:33:01,782 [MainThread  ] [INFO ]  Processing res.10200.txt.
# 2019-06-14 03:33:01,787 [MainThread  ] [INFO ]  Processing res.10201.txt.
# 2019-06-14 03:33:01,793 [MainThread  ] [INFO ]  Processing res.10202.txt.
# 2019-06-14 03:33:01,798 [MainThread  ] [INFO ]  Processing res.10203.txt.
# 2019-06-14 03:33:01,804 [MainThread  ] [INFO ]  Processing res.10204.txt.
# 2019-06-14 03:33:01,809 [MainThread  ] [INFO ]  Processing res.10205.txt.
# 2019-06-14 03:33:01,815 [MainThread  ] [INFO ]  Processing res.10206.txt.
# 2019-06-14 03:33:01,820 [MainThread  ] [INFO ]  Processing res.10207.txt.
# 2019-06-14 03:33:01,826 [MainThread  ] [INFO ]  Processing res.10208.txt.
# 2019-06-14 03:33:01,832 [MainThread  ] [INFO ]  Processing res.10209.txt.
# 2019-06-14 03:33:01,837 [MainThread  ] [INFO ]  Processing res.1021.txt.
# 2019-06-14 03:33:01,843 [MainThread  ] [INFO ]  Processing res.10210.txt.
# 2019-06-14 03:33:01,849 [MainThread  ] [INFO ]  Processing res.10211.txt.
# 2019-06-14 03:33:01,855 [MainThread  ] [INFO ]  Processing res.10212.txt.
# 2019-06-14 03:33:01,861 [MainThread  ] [INFO ]  Processing res.10213.txt.
# 2019-06-14 03:33:01,866 [MainThread  ] [INFO ]  Processing res.10214.txt.
# 2019-06-14 03:33:01,871 [MainThread  ] [INFO ]  Processing res.10215.txt.
# 2019-06-14 03:33:01,876 [MainThread  ] [INFO ]  Processing res.10216.txt.
# 2019-06-14 03:33:01,883 [MainThread  ] [INFO ]  Processing res.10217.txt.
# 2019-06-14 03:33:01,888 [MainThread  ] [INFO ]  Processing res.10218.txt.
# 2019-06-14 03:33:01,894 [MainThread  ] [INFO ]  Processing res.10219.txt.
# 2019-06-14 03:33:01,900 [MainThread  ] [INFO ]  Processing res.1022.txt.
# 2019-06-14 03:33:01,906 [MainThread  ] [INFO ]  Processing res.10220.txt.
# 2019-06-14 03:33:01,911 [MainThread  ] [INFO ]  Processing res.10221.txt.
# 2019-06-14 03:33:01,917 [MainThread  ] [INFO ]  Processing res.10222.txt.
# 2019-06-14 03:33:01,923 [MainThread  ] [INFO ]  Processing res.10223.txt.
# 2019-06-14 03:33:01,928 [MainThread  ] [INFO ]  Processing res.10224.txt.
# 2019-06-14 03:33:01,934 [MainThread  ] [INFO ]  Processing res.10225.txt.
# 2019-06-14 03:33:01,939 [MainThread  ] [INFO ]  Processing res.10226.txt.
# 2019-06-14 03:33:01,945 [MainThread  ] [INFO ]  Processing res.10227.txt.
# 2019-06-14 03:33:01,951 [MainThread  ] [INFO ]  Processing res.10228.txt.
# 2019-06-14 03:33:01,956 [MainThread  ] [INFO ]  Processing res.10229.txt.
# 2019-06-14 03:33:01,962 [MainThread  ] [INFO ]  Processing res.1023.txt.
# 2019-06-14 03:33:01,968 [MainThread  ] [INFO ]  Processing res.10230.txt.
# 2019-06-14 03:33:01,973 [MainThread  ] [INFO ]  Processing res.10231.txt.
# 2019-06-14 03:33:01,979 [MainThread  ] [INFO ]  Processing res.10232.txt.
# 2019-06-14 03:33:01,984 [MainThread  ] [INFO ]  Processing res.10233.txt.
# 2019-06-14 03:33:01,990 [MainThread  ] [INFO ]  Processing res.10234.txt.
# 2019-06-14 03:33:01,995 [MainThread  ] [INFO ]  Processing res.10235.txt.
# 2019-06-14 03:33:02,001 [MainThread  ] [INFO ]  Processing res.10236.txt.
# 2019-06-14 03:33:02,006 [MainThread  ] [INFO ]  Processing res.10237.txt.
# 2019-06-14 03:33:02,012 [MainThread  ] [INFO ]  Processing res.10238.txt.
# 2019-06-14 03:33:02,032 [MainThread  ] [INFO ]  Processing res.10239.txt.
# 2019-06-14 03:33:02,037 [MainThread  ] [INFO ]  Processing res.1024.txt.
# 2019-06-14 03:33:02,043 [MainThread  ] [INFO ]  Processing res.10240.txt.
# 2019-06-14 03:33:02,048 [MainThread  ] [INFO ]  Processing res.10241.txt.
# 2019-06-14 03:33:02,054 [MainThread  ] [INFO ]  Processing res.10242.txt.
# 2019-06-14 03:33:02,060 [MainThread  ] [INFO ]  Processing res.10243.txt.
# 2019-06-14 03:33:02,065 [MainThread  ] [INFO ]  Processing res.10244.txt.
# 2019-06-14 03:33:02,071 [MainThread  ] [INFO ]  Processing res.10245.txt.
# 2019-06-14 03:33:02,076 [MainThread  ] [INFO ]  Processing res.10246.txt.
# 2019-06-14 03:33:02,082 [MainThread  ] [INFO ]  Processing res.10247.txt.
# 2019-06-14 03:33:02,087 [MainThread  ] [INFO ]  Processing res.10248.txt.
# 2019-06-14 03:33:02,093 [MainThread  ] [INFO ]  Processing res.10249.txt.
# 2019-06-14 03:33:02,099 [MainThread  ] [INFO ]  Processing res.1025.txt.
# 2019-06-14 03:33:02,104 [MainThread  ] [INFO ]  Processing res.10250.txt.
# 2019-06-14 03:33:02,110 [MainThread  ] [INFO ]  Processing res.10251.txt.
# 2019-06-14 03:33:02,116 [MainThread  ] [INFO ]  Processing res.10252.txt.
# 2019-06-14 03:33:02,121 [MainThread  ] [INFO ]  Processing res.10253.txt.
# 2019-06-14 03:33:02,126 [MainThread  ] [INFO ]  Processing res.10254.txt.
# 2019-06-14 03:33:02,132 [MainThread  ] [INFO ]  Processing res.10255.txt.
# 2019-06-14 03:33:02,137 [MainThread  ] [INFO ]  Processing res.10256.txt.
# 2019-06-14 03:33:02,143 [MainThread  ] [INFO ]  Processing res.10257.txt.
# 2019-06-14 03:33:02,148 [MainThread  ] [INFO ]  Processing res.10258.txt.
# 2019-06-14 03:33:02,154 [MainThread  ] [INFO ]  Processing res.10259.txt.
# 2019-06-14 03:33:02,159 [MainThread  ] [INFO ]  Processing res.1026.txt.
# 2019-06-14 03:33:02,165 [MainThread  ] [INFO ]  Processing res.10260.txt.
# 2019-06-14 03:33:02,170 [MainThread  ] [INFO ]  Processing res.10261.txt.
# 2019-06-14 03:33:02,176 [MainThread  ] [INFO ]  Processing res.10262.txt.
# 2019-06-14 03:33:02,182 [MainThread  ] [INFO ]  Processing res.10263.txt.
# 2019-06-14 03:33:02,187 [MainThread  ] [INFO ]  Processing res.10264.txt.
# 2019-06-14 03:33:02,192 [MainThread  ] [INFO ]  Processing res.10265.txt.
# 2019-06-14 03:33:02,199 [MainThread  ] [INFO ]  Processing res.10266.txt.
# 2019-06-14 03:33:02,204 [MainThread  ] [INFO ]  Processing res.10267.txt.
# 2019-06-14 03:33:02,210 [MainThread  ] [INFO ]  Processing res.10268.txt.
# 2019-06-14 03:33:02,216 [MainThread  ] [INFO ]  Processing res.10269.txt.
# 2019-06-14 03:33:02,221 [MainThread  ] [INFO ]  Processing res.1027.txt.
# 2019-06-14 03:33:02,226 [MainThread  ] [INFO ]  Processing res.10270.txt.
# 2019-06-14 03:33:02,232 [MainThread  ] [INFO ]  Processing res.10271.txt.
# 2019-06-14 03:33:02,238 [MainThread  ] [INFO ]  Processing res.10272.txt.
# 2019-06-14 03:33:02,243 [MainThread  ] [INFO ]  Processing res.10273.txt.
# 2019-06-14 03:33:02,248 [MainThread  ] [INFO ]  Processing res.10274.txt.
# 2019-06-14 03:33:02,253 [MainThread  ] [INFO ]  Processing res.10275.txt.
# 2019-06-14 03:33:02,259 [MainThread  ] [INFO ]  Processing res.10276.txt.
# 2019-06-14 03:33:02,264 [MainThread  ] [INFO ]  Processing res.10277.txt.
# 2019-06-14 03:33:02,270 [MainThread  ] [INFO ]  Processing res.10278.txt.
# 2019-06-14 03:33:02,275 [MainThread  ] [INFO ]  Processing res.10279.txt.
# 2019-06-14 03:33:02,281 [MainThread  ] [INFO ]  Processing res.1028.txt.
# 2019-06-14 03:33:02,287 [MainThread  ] [INFO ]  Processing res.10280.txt.
# 2019-06-14 03:33:02,292 [MainThread  ] [INFO ]  Processing res.10281.txt.
# 2019-06-14 03:33:02,298 [MainThread  ] [INFO ]  Processing res.10282.txt.
# 2019-06-14 03:33:02,304 [MainThread  ] [INFO ]  Processing res.10283.txt.
# 2019-06-14 03:33:02,309 [MainThread  ] [INFO ]  Processing res.10284.txt.
# 2019-06-14 03:33:02,315 [MainThread  ] [INFO ]  Processing res.10285.txt.
# 2019-06-14 03:33:02,320 [MainThread  ] [INFO ]  Processing res.10286.txt.
# 2019-06-14 03:33:02,326 [MainThread  ] [INFO ]  Processing res.10287.txt.
# 2019-06-14 03:33:02,332 [MainThread  ] [INFO ]  Processing res.10288.txt.
# 2019-06-14 03:33:02,337 [MainThread  ] [INFO ]  Processing res.10289.txt.
# 2019-06-14 03:33:02,343 [MainThread  ] [INFO ]  Processing res.1029.txt.
# 2019-06-14 03:33:02,349 [MainThread  ] [INFO ]  Processing res.10290.txt.
# 2019-06-14 03:33:02,354 [MainThread  ] [INFO ]  Processing res.10291.txt.
# 2019-06-14 03:33:02,359 [MainThread  ] [INFO ]  Processing res.10292.txt.
# 2019-06-14 03:33:02,365 [MainThread  ] [INFO ]  Processing res.10293.txt.
# 2019-06-14 03:33:02,371 [MainThread  ] [INFO ]  Processing res.10294.txt.
# 2019-06-14 03:33:02,376 [MainThread  ] [INFO ]  Processing res.10295.txt.
# 2019-06-14 03:33:02,382 [MainThread  ] [INFO ]  Processing res.10296.txt.
# 2019-06-14 03:33:02,387 [MainThread  ] [INFO ]  Processing res.10297.txt.
# 2019-06-14 03:33:02,393 [MainThread  ] [INFO ]  Processing res.10298.txt.
# 2019-06-14 03:33:02,398 [MainThread  ] [INFO ]  Processing res.10299.txt.
# 2019-06-14 03:33:02,404 [MainThread  ] [INFO ]  Processing res.103.txt.
# 2019-06-14 03:33:02,410 [MainThread  ] [INFO ]  Processing res.1030.txt.
# 2019-06-14 03:33:02,416 [MainThread  ] [INFO ]  Processing res.10300.txt.
# 2019-06-14 03:33:02,421 [MainThread  ] [INFO ]  Processing res.10301.txt.
# 2019-06-14 03:33:02,427 [MainThread  ] [INFO ]  Processing res.10302.txt.
# 2019-06-14 03:33:02,433 [MainThread  ] [INFO ]  Processing res.10303.txt.
# 2019-06-14 03:33:02,438 [MainThread  ] [INFO ]  Processing res.10304.txt.
# 2019-06-14 03:33:02,444 [MainThread  ] [INFO ]  Processing res.10305.txt.
# 2019-06-14 03:33:02,449 [MainThread  ] [INFO ]  Processing res.10306.txt.
# 2019-06-14 03:33:02,455 [MainThread  ] [INFO ]  Processing res.10307.txt.
# 2019-06-14 03:33:02,461 [MainThread  ] [INFO ]  Processing res.10308.txt.
# 2019-06-14 03:33:02,466 [MainThread  ] [INFO ]  Processing res.10309.txt.
# 2019-06-14 03:33:02,472 [MainThread  ] [INFO ]  Processing res.1031.txt.
# 2019-06-14 03:33:02,477 [MainThread  ] [INFO ]  Processing res.10310.txt.
# 2019-06-14 03:33:02,483 [MainThread  ] [INFO ]  Processing res.10311.txt.
# 2019-06-14 03:33:02,488 [MainThread  ] [INFO ]  Processing res.10312.txt.
# 2019-06-14 03:33:02,494 [MainThread  ] [INFO ]  Processing res.10313.txt.
# 2019-06-14 03:33:02,500 [MainThread  ] [INFO ]  Processing res.10314.txt.
# 2019-06-14 03:33:02,505 [MainThread  ] [INFO ]  Processing res.10315.txt.
# 2019-06-14 03:33:02,511 [MainThread  ] [INFO ]  Processing res.10316.txt.
# 2019-06-14 03:33:02,517 [MainThread  ] [INFO ]  Processing res.10317.txt.
# 2019-06-14 03:33:02,522 [MainThread  ] [INFO ]  Processing res.10318.txt.
# 2019-06-14 03:33:02,528 [MainThread  ] [INFO ]  Processing res.10319.txt.
# 2019-06-14 03:33:02,533 [MainThread  ] [INFO ]  Processing res.1032.txt.
# 2019-06-14 03:33:02,539 [MainThread  ] [INFO ]  Processing res.10320.txt.
# 2019-06-14 03:33:02,545 [MainThread  ] [INFO ]  Processing res.10321.txt.
# 2019-06-14 03:33:02,551 [MainThread  ] [INFO ]  Processing res.10322.txt.
# 2019-06-14 03:33:02,556 [MainThread  ] [INFO ]  Processing res.10323.txt.
# 2019-06-14 03:33:02,562 [MainThread  ] [INFO ]  Processing res.10324.txt.
# 2019-06-14 03:33:02,567 [MainThread  ] [INFO ]  Processing res.10325.txt.
# 2019-06-14 03:33:02,573 [MainThread  ] [INFO ]  Processing res.10326.txt.
# 2019-06-14 03:33:02,578 [MainThread  ] [INFO ]  Processing res.10327.txt.
# 2019-06-14 03:33:02,584 [MainThread  ] [INFO ]  Processing res.10328.txt.
# 2019-06-14 03:33:02,589 [MainThread  ] [INFO ]  Processing res.10329.txt.
# 2019-06-14 03:33:02,595 [MainThread  ] [INFO ]  Processing res.1033.txt.
# 2019-06-14 03:33:02,601 [MainThread  ] [INFO ]  Processing res.10330.txt.
# 2019-06-14 03:33:02,606 [MainThread  ] [INFO ]  Processing res.10331.txt.
# 2019-06-14 03:33:02,612 [MainThread  ] [INFO ]  Processing res.10332.txt.
# 2019-06-14 03:33:02,616 [MainThread  ] [INFO ]  Processing res.10333.txt.
# 2019-06-14 03:33:02,622 [MainThread  ] [INFO ]  Processing res.10334.txt.
# 2019-06-14 03:33:02,627 [MainThread  ] [INFO ]  Processing res.10335.txt.
# 2019-06-14 03:33:02,633 [MainThread  ] [INFO ]  Processing res.10336.txt.
# 2019-06-14 03:33:02,639 [MainThread  ] [INFO ]  Processing res.10337.txt.
# 2019-06-14 03:33:02,644 [MainThread  ] [INFO ]  Processing res.10338.txt.
# 2019-06-14 03:33:02,650 [MainThread  ] [INFO ]  Processing res.10339.txt.
# 2019-06-14 03:33:02,656 [MainThread  ] [INFO ]  Processing res.1034.txt.
# 2019-06-14 03:33:02,661 [MainThread  ] [INFO ]  Processing res.10340.txt.
# 2019-06-14 03:33:02,667 [MainThread  ] [INFO ]  Processing res.10341.txt.
# 2019-06-14 03:33:02,673 [MainThread  ] [INFO ]  Processing res.10342.txt.
# 2019-06-14 03:33:02,678 [MainThread  ] [INFO ]  Processing res.10343.txt.
# 2019-06-14 03:33:02,684 [MainThread  ] [INFO ]  Processing res.10344.txt.
# 2019-06-14 03:33:02,690 [MainThread  ] [INFO ]  Processing res.10345.txt.
# 2019-06-14 03:33:02,695 [MainThread  ] [INFO ]  Processing res.10346.txt.
# 2019-06-14 03:33:02,701 [MainThread  ] [INFO ]  Processing res.10347.txt.
# 2019-06-14 03:33:02,719 [MainThread  ] [INFO ]  Processing res.10348.txt.
# 2019-06-14 03:33:02,724 [MainThread  ] [INFO ]  Processing res.10349.txt.
# 2019-06-14 03:33:02,735 [MainThread  ] [INFO ]  Processing res.1035.txt.
# 2019-06-14 03:33:02,740 [MainThread  ] [INFO ]  Processing res.10350.txt.
# 2019-06-14 03:33:02,746 [MainThread  ] [INFO ]  Processing res.10351.txt.
# 2019-06-14 03:33:02,752 [MainThread  ] [INFO ]  Processing res.10352.txt.
# 2019-06-14 03:33:02,758 [MainThread  ] [INFO ]  Processing res.10353.txt.
# 2019-06-14 03:33:02,763 [MainThread  ] [INFO ]  Processing res.10354.txt.
# 2019-06-14 03:33:02,769 [MainThread  ] [INFO ]  Processing res.10355.txt.
# 2019-06-14 03:33:02,774 [MainThread  ] [INFO ]  Processing res.10356.txt.
# 2019-06-14 03:33:02,780 [MainThread  ] [INFO ]  Processing res.10357.txt.
# 2019-06-14 03:33:02,786 [MainThread  ] [INFO ]  Processing res.10358.txt.
# 2019-06-14 03:33:02,791 [MainThread  ] [INFO ]  Processing res.10359.txt.
# 2019-06-14 03:33:02,796 [MainThread  ] [INFO ]  Processing res.1036.txt.
# 2019-06-14 03:33:02,802 [MainThread  ] [INFO ]  Processing res.10360.txt.
# 2019-06-14 03:33:02,808 [MainThread  ] [INFO ]  Processing res.10361.txt.
# 2019-06-14 03:33:02,813 [MainThread  ] [INFO ]  Processing res.10362.txt.
# 2019-06-14 03:33:02,819 [MainThread  ] [INFO ]  Processing res.10363.txt.
# 2019-06-14 03:33:02,825 [MainThread  ] [INFO ]  Processing res.10364.txt.
# 2019-06-14 03:33:02,830 [MainThread  ] [INFO ]  Processing res.10365.txt.
# 2019-06-14 03:33:02,837 [MainThread  ] [INFO ]  Processing res.10366.txt.
# 2019-06-14 03:33:02,842 [MainThread  ] [INFO ]  Processing res.10367.txt.
# 2019-06-14 03:33:02,848 [MainThread  ] [INFO ]  Processing res.10368.txt.
# 2019-06-14 03:33:02,854 [MainThread  ] [INFO ]  Processing res.10369.txt.
# 2019-06-14 03:33:02,860 [MainThread  ] [INFO ]  Processing res.1037.txt.
# 2019-06-14 03:33:02,866 [MainThread  ] [INFO ]  Processing res.10370.txt.
# 2019-06-14 03:33:02,871 [MainThread  ] [INFO ]  Processing res.10371.txt.
# 2019-06-14 03:33:02,877 [MainThread  ] [INFO ]  Processing res.10372.txt.
# 2019-06-14 03:33:02,882 [MainThread  ] [INFO ]  Processing res.10373.txt.
# 2019-06-14 03:33:02,888 [MainThread  ] [INFO ]  Processing res.10374.txt.
# 2019-06-14 03:33:02,893 [MainThread  ] [INFO ]  Processing res.10375.txt.
# 2019-06-14 03:33:02,899 [MainThread  ] [INFO ]  Processing res.10376.txt.
# 2019-06-14 03:33:02,905 [MainThread  ] [INFO ]  Processing res.10377.txt.
# 2019-06-14 03:33:02,910 [MainThread  ] [INFO ]  Processing res.10378.txt.
# 2019-06-14 03:33:02,916 [MainThread  ] [INFO ]  Processing res.10379.txt.
# 2019-06-14 03:33:02,922 [MainThread  ] [INFO ]  Processing res.1038.txt.
# 2019-06-14 03:33:02,927 [MainThread  ] [INFO ]  Processing res.10380.txt.
# 2019-06-14 03:33:02,933 [MainThread  ] [INFO ]  Processing res.10381.txt.
# 2019-06-14 03:33:02,939 [MainThread  ] [INFO ]  Processing res.10382.txt.
# 2019-06-14 03:33:02,944 [MainThread  ] [INFO ]  Processing res.10383.txt.
# 2019-06-14 03:33:02,950 [MainThread  ] [INFO ]  Processing res.10384.txt.
# 2019-06-14 03:33:02,956 [MainThread  ] [INFO ]  Processing res.10385.txt.
# 2019-06-14 03:33:02,961 [MainThread  ] [INFO ]  Processing res.10386.txt.
# 2019-06-14 03:33:02,967 [MainThread  ] [INFO ]  Processing res.10387.txt.
# 2019-06-14 03:33:02,972 [MainThread  ] [INFO ]  Processing res.10388.txt.
# 2019-06-14 03:33:02,978 [MainThread  ] [INFO ]  Processing res.10389.txt.
# 2019-06-14 03:33:02,983 [MainThread  ] [INFO ]  Processing res.1039.txt.
# 2019-06-14 03:33:02,988 [MainThread  ] [INFO ]  Processing res.10390.txt.
# 2019-06-14 03:33:02,993 [MainThread  ] [INFO ]  Processing res.10391.txt.
# 2019-06-14 03:33:02,999 [MainThread  ] [INFO ]  Processing res.10392.txt.
# 2019-06-14 03:33:03,005 [MainThread  ] [INFO ]  Processing res.10393.txt.
# 2019-06-14 03:33:03,011 [MainThread  ] [INFO ]  Processing res.10394.txt.
# 2019-06-14 03:33:03,016 [MainThread  ] [INFO ]  Processing res.10395.txt.
# 2019-06-14 03:33:03,025 [MainThread  ] [INFO ]  Processing res.10396.txt.
# 2019-06-14 03:33:03,031 [MainThread  ] [INFO ]  Processing res.10397.txt.
# 2019-06-14 03:33:03,036 [MainThread  ] [INFO ]  Processing res.10398.txt.
# 2019-06-14 03:33:03,042 [MainThread  ] [INFO ]  Processing res.10399.txt.
# 2019-06-14 03:33:03,047 [MainThread  ] [INFO ]  Processing res.104.txt.
# 2019-06-14 03:33:03,053 [MainThread  ] [INFO ]  Processing res.1040.txt.
# 2019-06-14 03:33:03,059 [MainThread  ] [INFO ]  Processing res.10400.txt.
# 2019-06-14 03:33:03,065 [MainThread  ] [INFO ]  Processing res.10401.txt.
# 2019-06-14 03:33:03,070 [MainThread  ] [INFO ]  Processing res.10402.txt.
# 2019-06-14 03:33:03,076 [MainThread  ] [INFO ]  Processing res.10403.txt.
# 2019-06-14 03:33:03,082 [MainThread  ] [INFO ]  Processing res.10404.txt.
# 2019-06-14 03:33:03,088 [MainThread  ] [INFO ]  Processing res.10405.txt.
# 2019-06-14 03:33:03,093 [MainThread  ] [INFO ]  Processing res.10406.txt.
# 2019-06-14 03:33:03,099 [MainThread  ] [INFO ]  Processing res.10407.txt.
# 2019-06-14 03:33:03,104 [MainThread  ] [INFO ]  Processing res.10408.txt.
# 2019-06-14 03:33:03,109 [MainThread  ] [INFO ]  Processing res.10409.txt.
# 2019-06-14 03:33:03,115 [MainThread  ] [INFO ]  Processing res.1041.txt.
# 2019-06-14 03:33:03,121 [MainThread  ] [INFO ]  Processing res.10410.txt.
# 2019-06-14 03:33:03,126 [MainThread  ] [INFO ]  Processing res.10411.txt.
# 2019-06-14 03:33:03,132 [MainThread  ] [INFO ]  Processing res.10412.txt.
# 2019-06-14 03:33:03,137 [MainThread  ] [INFO ]  Processing res.10413.txt.
# 2019-06-14 03:33:03,143 [MainThread  ] [INFO ]  Processing res.10414.txt.
# 2019-06-14 03:33:03,149 [MainThread  ] [INFO ]  Processing res.10415.txt.
# 2019-06-14 03:33:03,154 [MainThread  ] [INFO ]  Processing res.10416.txt.
# 2019-06-14 03:33:03,159 [MainThread  ] [INFO ]  Processing res.10417.txt.
# 2019-06-14 03:33:03,165 [MainThread  ] [INFO ]  Processing res.10418.txt.
# 2019-06-14 03:33:03,171 [MainThread  ] [INFO ]  Processing res.10419.txt.
# 2019-06-14 03:33:03,176 [MainThread  ] [INFO ]  Processing res.1042.txt.
# 2019-06-14 03:33:03,182 [MainThread  ] [INFO ]  Processing res.10420.txt.
# 2019-06-14 03:33:03,187 [MainThread  ] [INFO ]  Processing res.10421.txt.
# 2019-06-14 03:33:03,193 [MainThread  ] [INFO ]  Processing res.10422.txt.
# 2019-06-14 03:33:03,198 [MainThread  ] [INFO ]  Processing res.10423.txt.
# 2019-06-14 03:33:03,204 [MainThread  ] [INFO ]  Processing res.10424.txt.
# 2019-06-14 03:33:03,209 [MainThread  ] [INFO ]  Processing res.10425.txt.
# 2019-06-14 03:33:03,215 [MainThread  ] [INFO ]  Processing res.10426.txt.
# 2019-06-14 03:33:03,220 [MainThread  ] [INFO ]  Processing res.10427.txt.
# 2019-06-14 03:33:03,226 [MainThread  ] [INFO ]  Processing res.10428.txt.
# 2019-06-14 03:33:03,232 [MainThread  ] [INFO ]  Processing res.10429.txt.
# 2019-06-14 03:33:03,237 [MainThread  ] [INFO ]  Processing res.1043.txt.
# 2019-06-14 03:33:03,243 [MainThread  ] [INFO ]  Processing res.10430.txt.
# 2019-06-14 03:33:03,249 [MainThread  ] [INFO ]  Processing res.10431.txt.
# 2019-06-14 03:33:03,254 [MainThread  ] [INFO ]  Processing res.10432.txt.
# 2019-06-14 03:33:03,259 [MainThread  ] [INFO ]  Processing res.10433.txt.
# 2019-06-14 03:33:03,265 [MainThread  ] [INFO ]  Processing res.10434.txt.
# 2019-06-14 03:33:03,271 [MainThread  ] [INFO ]  Processing res.10435.txt.
# 2019-06-14 03:33:03,276 [MainThread  ] [INFO ]  Processing res.10436.txt.
# 2019-06-14 03:33:03,282 [MainThread  ] [INFO ]  Processing res.10437.txt.
# 2019-06-14 03:33:03,287 [MainThread  ] [INFO ]  Processing res.10438.txt.
# 2019-06-14 03:33:03,293 [MainThread  ] [INFO ]  Processing res.10439.txt.
# 2019-06-14 03:33:03,299 [MainThread  ] [INFO ]  Processing res.1044.txt.
# 2019-06-14 03:33:03,304 [MainThread  ] [INFO ]  Processing res.10440.txt.
# 2019-06-14 03:33:03,309 [MainThread  ] [INFO ]  Processing res.10441.txt.
# 2019-06-14 03:33:03,315 [MainThread  ] [INFO ]  Processing res.10442.txt.
# 2019-06-14 03:33:03,320 [MainThread  ] [INFO ]  Processing res.10443.txt.
# 2019-06-14 03:33:03,326 [MainThread  ] [INFO ]  Processing res.10444.txt.
# 2019-06-14 03:33:03,332 [MainThread  ] [INFO ]  Processing res.10445.txt.
# 2019-06-14 03:33:03,337 [MainThread  ] [INFO ]  Processing res.10446.txt.
# 2019-06-14 03:33:03,343 [MainThread  ] [INFO ]  Processing res.10447.txt.
# 2019-06-14 03:33:03,348 [MainThread  ] [INFO ]  Processing res.10448.txt.
# 2019-06-14 03:33:03,354 [MainThread  ] [INFO ]  Processing res.10449.txt.
# 2019-06-14 03:33:03,359 [MainThread  ] [INFO ]  Processing res.1045.txt.
# 2019-06-14 03:33:03,364 [MainThread  ] [INFO ]  Processing res.10450.txt.
# 2019-06-14 03:33:03,370 [MainThread  ] [INFO ]  Processing res.10451.txt.
# 2019-06-14 03:33:03,375 [MainThread  ] [INFO ]  Processing res.10452.txt.
# 2019-06-14 03:33:03,381 [MainThread  ] [INFO ]  Processing res.10453.txt.
# 2019-06-14 03:33:03,386 [MainThread  ] [INFO ]  Processing res.10454.txt.
# 2019-06-14 03:33:03,392 [MainThread  ] [INFO ]  Processing res.10455.txt.
# 2019-06-14 03:33:03,405 [MainThread  ] [INFO ]  Processing res.10456.txt.
# 2019-06-14 03:33:03,411 [MainThread  ] [INFO ]  Processing res.10457.txt.
# 2019-06-14 03:33:03,416 [MainThread  ] [INFO ]  Processing res.10458.txt.
# 2019-06-14 03:33:03,422 [MainThread  ] [INFO ]  Processing res.10459.txt.
# 2019-06-14 03:33:03,427 [MainThread  ] [INFO ]  Processing res.1046.txt.
# 2019-06-14 03:33:03,433 [MainThread  ] [INFO ]  Processing res.10460.txt.
# 2019-06-14 03:33:03,438 [MainThread  ] [INFO ]  Processing res.10461.txt.
# 2019-06-14 03:33:03,444 [MainThread  ] [INFO ]  Processing res.10462.txt.
# 2019-06-14 03:33:03,449 [MainThread  ] [INFO ]  Processing res.10463.txt.
# 2019-06-14 03:33:03,455 [MainThread  ] [INFO ]  Processing res.10464.txt.
# 2019-06-14 03:33:03,460 [MainThread  ] [INFO ]  Processing res.10465.txt.
# 2019-06-14 03:33:03,466 [MainThread  ] [INFO ]  Processing res.10466.txt.
# 2019-06-14 03:33:03,472 [MainThread  ] [INFO ]  Processing res.10467.txt.
# 2019-06-14 03:33:03,477 [MainThread  ] [INFO ]  Processing res.10468.txt.
# 2019-06-14 03:33:03,482 [MainThread  ] [INFO ]  Processing res.10469.txt.
# 2019-06-14 03:33:03,488 [MainThread  ] [INFO ]  Processing res.1047.txt.
# 2019-06-14 03:33:03,494 [MainThread  ] [INFO ]  Processing res.10470.txt.
# 2019-06-14 03:33:03,499 [MainThread  ] [INFO ]  Processing res.10471.txt.
# 2019-06-14 03:33:03,505 [MainThread  ] [INFO ]  Processing res.10472.txt.
# 2019-06-14 03:33:03,510 [MainThread  ] [INFO ]  Processing res.10473.txt.
# 2019-06-14 03:33:03,516 [MainThread  ] [INFO ]  Processing res.10474.txt.
# 2019-06-14 03:33:03,522 [MainThread  ] [INFO ]  Processing res.10475.txt.
# 2019-06-14 03:33:03,527 [MainThread  ] [INFO ]  Processing res.10476.txt.
# 2019-06-14 03:33:03,533 [MainThread  ] [INFO ]  Processing res.10477.txt.
# 2019-06-14 03:33:03,539 [MainThread  ] [INFO ]  Processing res.10478.txt.
# 2019-06-14 03:33:03,544 [MainThread  ] [INFO ]  Processing res.10479.txt.
# 2019-06-14 03:33:03,550 [MainThread  ] [INFO ]  Processing res.1048.txt.
# 2019-06-14 03:33:03,557 [MainThread  ] [INFO ]  Processing res.10480.txt.
# 2019-06-14 03:33:03,563 [MainThread  ] [INFO ]  Processing res.10481.txt.
# 2019-06-14 03:33:03,569 [MainThread  ] [INFO ]  Processing res.10482.txt.
# 2019-06-14 03:33:03,574 [MainThread  ] [INFO ]  Processing res.10483.txt.
# 2019-06-14 03:33:03,580 [MainThread  ] [INFO ]  Processing res.10484.txt.
# 2019-06-14 03:33:03,586 [MainThread  ] [INFO ]  Processing res.10485.txt.
# 2019-06-14 03:33:03,591 [MainThread  ] [INFO ]  Processing res.10486.txt.
# 2019-06-14 03:33:03,596 [MainThread  ] [INFO ]  Processing res.10487.txt.
# 2019-06-14 03:33:03,603 [MainThread  ] [INFO ]  Processing res.10488.txt.
# 2019-06-14 03:33:03,608 [MainThread  ] [INFO ]  Processing res.10489.txt.
# 2019-06-14 03:33:03,613 [MainThread  ] [INFO ]  Processing res.1049.txt.
# 2019-06-14 03:33:03,619 [MainThread  ] [INFO ]  Processing res.10490.txt.
# 2019-06-14 03:33:03,625 [MainThread  ] [INFO ]  Processing res.10491.txt.
# 2019-06-14 03:33:03,630 [MainThread  ] [INFO ]  Processing res.10492.txt.
# 2019-06-14 03:33:03,636 [MainThread  ] [INFO ]  Processing res.10493.txt.
# 2019-06-14 03:33:03,641 [MainThread  ] [INFO ]  Processing res.10494.txt.
# 2019-06-14 03:33:03,647 [MainThread  ] [INFO ]  Processing res.10495.txt.
# 2019-06-14 03:33:03,652 [MainThread  ] [INFO ]  Processing res.10496.txt.
# 2019-06-14 03:33:03,658 [MainThread  ] [INFO ]  Processing res.10497.txt.
# 2019-06-14 03:33:03,664 [MainThread  ] [INFO ]  Processing res.10498.txt.
# 2019-06-14 03:33:03,669 [MainThread  ] [INFO ]  Processing res.10499.txt.
# 2019-06-14 03:33:03,675 [MainThread  ] [INFO ]  Processing res.105.txt.
# 2019-06-14 03:33:03,681 [MainThread  ] [INFO ]  Processing res.1050.txt.
# 2019-06-14 03:33:03,686 [MainThread  ] [INFO ]  Processing res.10500.txt.
# 2019-06-14 03:33:03,692 [MainThread  ] [INFO ]  Processing res.10501.txt.
# 2019-06-14 03:33:03,697 [MainThread  ] [INFO ]  Processing res.10502.txt.
# 2019-06-14 03:33:03,703 [MainThread  ] [INFO ]  Processing res.10503.txt.
# 2019-06-14 03:33:03,708 [MainThread  ] [INFO ]  Processing res.10504.txt.
# 2019-06-14 03:33:03,714 [MainThread  ] [INFO ]  Processing res.10505.txt.
# 2019-06-14 03:33:03,719 [MainThread  ] [INFO ]  Processing res.10506.txt.
# 2019-06-14 03:33:03,725 [MainThread  ] [INFO ]  Processing res.10507.txt.
# 2019-06-14 03:33:03,730 [MainThread  ] [INFO ]  Processing res.10508.txt.
# 2019-06-14 03:33:03,736 [MainThread  ] [INFO ]  Processing res.10509.txt.
# 2019-06-14 03:33:03,741 [MainThread  ] [INFO ]  Processing res.1051.txt.
# 2019-06-14 03:33:03,746 [MainThread  ] [INFO ]  Processing res.10510.txt.
# 2019-06-14 03:33:03,752 [MainThread  ] [INFO ]  Processing res.10511.txt.
# 2019-06-14 03:33:03,757 [MainThread  ] [INFO ]  Processing res.10512.txt.
# 2019-06-14 03:33:03,763 [MainThread  ] [INFO ]  Processing res.10513.txt.
# 2019-06-14 03:33:03,768 [MainThread  ] [INFO ]  Processing res.10514.txt.
# 2019-06-14 03:33:03,774 [MainThread  ] [INFO ]  Processing res.10515.txt.
# 2019-06-14 03:33:03,780 [MainThread  ] [INFO ]  Processing res.10516.txt.
# 2019-06-14 03:33:03,785 [MainThread  ] [INFO ]  Processing res.10517.txt.
# 2019-06-14 03:33:03,791 [MainThread  ] [INFO ]  Processing res.10518.txt.
# 2019-06-14 03:33:03,796 [MainThread  ] [INFO ]  Processing res.10519.txt.
# 2019-06-14 03:33:03,802 [MainThread  ] [INFO ]  Processing res.1052.txt.
# 2019-06-14 03:33:03,807 [MainThread  ] [INFO ]  Processing res.10520.txt.
# 2019-06-14 03:33:03,813 [MainThread  ] [INFO ]  Processing res.10521.txt.
# 2019-06-14 03:33:03,819 [MainThread  ] [INFO ]  Processing res.10522.txt.
# 2019-06-14 03:33:03,824 [MainThread  ] [INFO ]  Processing res.10523.txt.
# 2019-06-14 03:33:03,830 [MainThread  ] [INFO ]  Processing res.10524.txt.
# 2019-06-14 03:33:03,835 [MainThread  ] [INFO ]  Processing res.10525.txt.
# 2019-06-14 03:33:03,841 [MainThread  ] [INFO ]  Processing res.10526.txt.
# 2019-06-14 03:33:03,847 [MainThread  ] [INFO ]  Processing res.10527.txt.
# 2019-06-14 03:33:03,852 [MainThread  ] [INFO ]  Processing res.10528.txt.
# 2019-06-14 03:33:03,858 [MainThread  ] [INFO ]  Processing res.10529.txt.
# 2019-06-14 03:33:03,864 [MainThread  ] [INFO ]  Processing res.1053.txt.
# 2019-06-14 03:33:03,869 [MainThread  ] [INFO ]  Processing res.10530.txt.
# 2019-06-14 03:33:03,875 [MainThread  ] [INFO ]  Processing res.10531.txt.
# 2019-06-14 03:33:03,881 [MainThread  ] [INFO ]  Processing res.10532.txt.
# 2019-06-14 03:33:03,886 [MainThread  ] [INFO ]  Processing res.10533.txt.
# 2019-06-14 03:33:03,891 [MainThread  ] [INFO ]  Processing res.10534.txt.
# 2019-06-14 03:33:03,897 [MainThread  ] [INFO ]  Processing res.10535.txt.
# 2019-06-14 03:33:03,903 [MainThread  ] [INFO ]  Processing res.10536.txt.
# 2019-06-14 03:33:03,908 [MainThread  ] [INFO ]  Processing res.10537.txt.
# 2019-06-14 03:33:03,914 [MainThread  ] [INFO ]  Processing res.10538.txt.
# 2019-06-14 03:33:03,920 [MainThread  ] [INFO ]  Processing res.10539.txt.
# 2019-06-14 03:33:03,925 [MainThread  ] [INFO ]  Processing res.1054.txt.
# 2019-06-14 03:33:03,932 [MainThread  ] [INFO ]  Processing res.10540.txt.
# 2019-06-14 03:33:03,937 [MainThread  ] [INFO ]  Processing res.10541.txt.
# 2019-06-14 03:33:03,942 [MainThread  ] [INFO ]  Processing res.10542.txt.
# 2019-06-14 03:33:03,948 [MainThread  ] [INFO ]  Processing res.10543.txt.
# 2019-06-14 03:33:03,954 [MainThread  ] [INFO ]  Processing res.10544.txt.
# 2019-06-14 03:33:03,959 [MainThread  ] [INFO ]  Processing res.10545.txt.
# 2019-06-14 03:33:03,965 [MainThread  ] [INFO ]  Processing res.10546.txt.
# 2019-06-14 03:33:03,971 [MainThread  ] [INFO ]  Processing res.10547.txt.
# 2019-06-14 03:33:03,976 [MainThread  ] [INFO ]  Processing res.10548.txt.
# 2019-06-14 03:33:03,982 [MainThread  ] [INFO ]  Processing res.10549.txt.
# 2019-06-14 03:33:03,988 [MainThread  ] [INFO ]  Processing res.1055.txt.
# 2019-06-14 03:33:03,993 [MainThread  ] [INFO ]  Processing res.10550.txt.
# 2019-06-14 03:33:03,999 [MainThread  ] [INFO ]  Processing res.10551.txt.
# 2019-06-14 03:33:04,005 [MainThread  ] [INFO ]  Processing res.10552.txt.
# 2019-06-14 03:33:04,011 [MainThread  ] [INFO ]  Processing res.10553.txt.
# 2019-06-14 03:33:04,016 [MainThread  ] [INFO ]  Processing res.10554.txt.
# 2019-06-14 03:33:04,022 [MainThread  ] [INFO ]  Processing res.10555.txt.
# 2019-06-14 03:33:04,027 [MainThread  ] [INFO ]  Processing res.10556.txt.
# 2019-06-14 03:33:04,033 [MainThread  ] [INFO ]  Processing res.10557.txt.
# 2019-06-14 03:33:04,038 [MainThread  ] [INFO ]  Processing res.10558.txt.
# 2019-06-14 03:33:04,044 [MainThread  ] [INFO ]  Processing res.10559.txt.
# 2019-06-14 03:33:04,049 [MainThread  ] [INFO ]  Processing res.1056.txt.
# 2019-06-14 03:33:04,055 [MainThread  ] [INFO ]  Processing res.10560.txt.
# 2019-06-14 03:33:04,060 [MainThread  ] [INFO ]  Processing res.10561.txt.
# 2019-06-14 03:33:04,066 [MainThread  ] [INFO ]  Processing res.10562.txt.
# 2019-06-14 03:33:04,071 [MainThread  ] [INFO ]  Processing res.10563.txt.
# 2019-06-14 03:33:04,077 [MainThread  ] [INFO ]  Processing res.10564.txt.
# 2019-06-14 03:33:04,083 [MainThread  ] [INFO ]  Processing res.10565.txt.
# 2019-06-14 03:33:04,088 [MainThread  ] [INFO ]  Processing res.10566.txt.
# 2019-06-14 03:33:04,093 [MainThread  ] [INFO ]  Processing res.10567.txt.
# 2019-06-14 03:33:04,099 [MainThread  ] [INFO ]  Processing res.10568.txt.
# 2019-06-14 03:33:04,105 [MainThread  ] [INFO ]  Processing res.10569.txt.
# 2019-06-14 03:33:04,110 [MainThread  ] [INFO ]  Processing res.1057.txt.
# 2019-06-14 03:33:04,116 [MainThread  ] [INFO ]  Processing res.10570.txt.
# 2019-06-14 03:33:04,121 [MainThread  ] [INFO ]  Processing res.10571.txt.
# 2019-06-14 03:33:04,126 [MainThread  ] [INFO ]  Processing res.10572.txt.
# 2019-06-14 03:33:04,132 [MainThread  ] [INFO ]  Processing res.10573.txt.
# 2019-06-14 03:33:04,137 [MainThread  ] [INFO ]  Processing res.10574.txt.
# 2019-06-14 03:33:04,143 [MainThread  ] [INFO ]  Processing res.10575.txt.
# 2019-06-14 03:33:04,148 [MainThread  ] [INFO ]  Processing res.10576.txt.
# ...
# 2019-06-14 03:35:09,685 [MainThread  ] [INFO ]  Processing ref.9832.txt.
# 2019-06-14 03:35:09,690 [MainThread  ] [INFO ]  Processing ref.9833.txt.
# 2019-06-14 03:35:09,695 [MainThread  ] [INFO ]  Processing ref.9834.txt.
# 2019-06-14 03:35:09,701 [MainThread  ] [INFO ]  Processing ref.9835.txt.
# 2019-06-14 03:35:09,706 [MainThread  ] [INFO ]  Processing ref.9836.txt.
# 2019-06-14 03:35:09,712 [MainThread  ] [INFO ]  Processing ref.9837.txt.
# 2019-06-14 03:35:09,717 [MainThread  ] [INFO ]  Processing ref.9838.txt.
# 2019-06-14 03:35:09,723 [MainThread  ] [INFO ]  Processing ref.9839.txt.
# 2019-06-14 03:35:09,728 [MainThread  ] [INFO ]  Processing ref.984.txt.
# 2019-06-14 03:35:09,734 [MainThread  ] [INFO ]  Processing ref.9840.txt.
# 2019-06-14 03:35:09,739 [MainThread  ] [INFO ]  Processing ref.9841.txt.
# 2019-06-14 03:35:09,745 [MainThread  ] [INFO ]  Processing ref.9842.txt.
# 2019-06-14 03:35:09,750 [MainThread  ] [INFO ]  Processing ref.9843.txt.
# 2019-06-14 03:35:09,756 [MainThread  ] [INFO ]  Processing ref.9844.txt.
# 2019-06-14 03:35:09,762 [MainThread  ] [INFO ]  Processing ref.9845.txt.
# 2019-06-14 03:35:09,767 [MainThread  ] [INFO ]  Processing ref.9846.txt.
# 2019-06-14 03:35:09,773 [MainThread  ] [INFO ]  Processing ref.9847.txt.
# 2019-06-14 03:35:09,778 [MainThread  ] [INFO ]  Processing ref.9848.txt.
# 2019-06-14 03:35:09,784 [MainThread  ] [INFO ]  Processing ref.9849.txt.
# 2019-06-14 03:35:09,789 [MainThread  ] [INFO ]  Processing ref.985.txt.
# 2019-06-14 03:35:09,795 [MainThread  ] [INFO ]  Processing ref.9850.txt.
# 2019-06-14 03:35:09,800 [MainThread  ] [INFO ]  Processing ref.9851.txt.
# 2019-06-14 03:35:09,806 [MainThread  ] [INFO ]  Processing ref.9852.txt.
# 2019-06-14 03:35:09,811 [MainThread  ] [INFO ]  Processing ref.9853.txt.
# 2019-06-14 03:35:09,817 [MainThread  ] [INFO ]  Processing ref.9854.txt.
# 2019-06-14 03:35:09,823 [MainThread  ] [INFO ]  Processing ref.9855.txt.
# 2019-06-14 03:35:09,829 [MainThread  ] [INFO ]  Processing ref.9856.txt.
# 2019-06-14 03:35:09,834 [MainThread  ] [INFO ]  Processing ref.9857.txt.
# 2019-06-14 03:35:09,840 [MainThread  ] [INFO ]  Processing ref.9858.txt.
# 2019-06-14 03:35:09,846 [MainThread  ] [INFO ]  Processing ref.9859.txt.
# 2019-06-14 03:35:09,852 [MainThread  ] [INFO ]  Processing ref.986.txt.
# 2019-06-14 03:35:09,858 [MainThread  ] [INFO ]  Processing ref.9860.txt.
# 2019-06-14 03:35:09,864 [MainThread  ] [INFO ]  Processing ref.9861.txt.
# 2019-06-14 03:35:09,869 [MainThread  ] [INFO ]  Processing ref.9862.txt.
# 2019-06-14 03:35:09,874 [MainThread  ] [INFO ]  Processing ref.9863.txt.
# 2019-06-14 03:35:09,880 [MainThread  ] [INFO ]  Processing ref.9864.txt.
# 2019-06-14 03:35:09,885 [MainThread  ] [INFO ]  Processing ref.9865.txt.
# 2019-06-14 03:35:09,891 [MainThread  ] [INFO ]  Processing ref.9866.txt.
# 2019-06-14 03:35:09,897 [MainThread  ] [INFO ]  Processing ref.9867.txt.
# 2019-06-14 03:35:09,902 [MainThread  ] [INFO ]  Processing ref.9868.txt.
# 2019-06-14 03:35:09,908 [MainThread  ] [INFO ]  Processing ref.9869.txt.
# 2019-06-14 03:35:09,914 [MainThread  ] [INFO ]  Processing ref.987.txt.
# 2019-06-14 03:35:09,919 [MainThread  ] [INFO ]  Processing ref.9870.txt.
# 2019-06-14 03:35:09,925 [MainThread  ] [INFO ]  Processing ref.9871.txt.
# 2019-06-14 03:35:09,931 [MainThread  ] [INFO ]  Processing ref.9872.txt.
# 2019-06-14 03:35:09,936 [MainThread  ] [INFO ]  Processing ref.9873.txt.
# 2019-06-14 03:35:09,941 [MainThread  ] [INFO ]  Processing ref.9874.txt.
# 2019-06-14 03:35:09,947 [MainThread  ] [INFO ]  Processing ref.9875.txt.
# 2019-06-14 03:35:09,953 [MainThread  ] [INFO ]  Processing ref.9876.txt.
# 2019-06-14 03:35:09,958 [MainThread  ] [INFO ]  Processing ref.9877.txt.
# 2019-06-14 03:35:09,964 [MainThread  ] [INFO ]  Processing ref.9878.txt.
# 2019-06-14 03:35:09,969 [MainThread  ] [INFO ]  Processing ref.9879.txt.
# 2019-06-14 03:35:09,975 [MainThread  ] [INFO ]  Processing ref.988.txt.
# 2019-06-14 03:35:09,981 [MainThread  ] [INFO ]  Processing ref.9880.txt.
# 2019-06-14 03:35:09,986 [MainThread  ] [INFO ]  Processing ref.9881.txt.
# 2019-06-14 03:35:09,991 [MainThread  ] [INFO ]  Processing ref.9882.txt.
# 2019-06-14 03:35:09,998 [MainThread  ] [INFO ]  Processing ref.9883.txt.
# 2019-06-14 03:35:10,003 [MainThread  ] [INFO ]  Processing ref.9884.txt.
# 2019-06-14 03:35:10,009 [MainThread  ] [INFO ]  Processing ref.9885.txt.
# 2019-06-14 03:35:10,014 [MainThread  ] [INFO ]  Processing ref.9886.txt.
# 2019-06-14 03:35:10,020 [MainThread  ] [INFO ]  Processing ref.9887.txt.
# 2019-06-14 03:35:10,026 [MainThread  ] [INFO ]  Processing ref.9888.txt.
# 2019-06-14 03:35:10,032 [MainThread  ] [INFO ]  Processing ref.9889.txt.
# 2019-06-14 03:35:10,037 [MainThread  ] [INFO ]  Processing ref.989.txt.
# 2019-06-14 03:35:10,043 [MainThread  ] [INFO ]  Processing ref.9890.txt.
# 2019-06-14 03:35:10,048 [MainThread  ] [INFO ]  Processing ref.9891.txt.
# 2019-06-14 03:35:10,054 [MainThread  ] [INFO ]  Processing ref.9892.txt.
# 2019-06-14 03:35:10,060 [MainThread  ] [INFO ]  Processing ref.9893.txt.
# 2019-06-14 03:35:10,065 [MainThread  ] [INFO ]  Processing ref.9894.txt.
# 2019-06-14 03:35:10,070 [MainThread  ] [INFO ]  Processing ref.9895.txt.
# 2019-06-14 03:35:10,075 [MainThread  ] [INFO ]  Processing ref.9896.txt.
# 2019-06-14 03:35:10,081 [MainThread  ] [INFO ]  Processing ref.9897.txt.
# 2019-06-14 03:35:10,086 [MainThread  ] [INFO ]  Processing ref.9898.txt.
# 2019-06-14 03:35:10,092 [MainThread  ] [INFO ]  Processing ref.9899.txt.
# 2019-06-14 03:35:10,098 [MainThread  ] [INFO ]  Processing ref.99.txt.
# 2019-06-14 03:35:10,103 [MainThread  ] [INFO ]  Processing ref.990.txt.
# 2019-06-14 03:35:10,105 [MainThread  ] [INFO ]  Processing ref.9900.txt.
# 2019-06-14 03:35:10,111 [MainThread  ] [INFO ]  Processing ref.9901.txt.
# 2019-06-14 03:35:10,116 [MainThread  ] [INFO ]  Processing ref.9902.txt.
# 2019-06-14 03:35:10,122 [MainThread  ] [INFO ]  Processing ref.9903.txt.
# 2019-06-14 03:35:10,128 [MainThread  ] [INFO ]  Processing ref.9904.txt.
# 2019-06-14 03:35:10,133 [MainThread  ] [INFO ]  Processing ref.9905.txt.
# 2019-06-14 03:35:10,139 [MainThread  ] [INFO ]  Processing ref.9906.txt.
# 2019-06-14 03:35:10,144 [MainThread  ] [INFO ]  Processing ref.9907.txt.
# 2019-06-14 03:35:10,150 [MainThread  ] [INFO ]  Processing ref.9908.txt.
# 2019-06-14 03:35:10,155 [MainThread  ] [INFO ]  Processing ref.9909.txt.
# 2019-06-14 03:35:10,161 [MainThread  ] [INFO ]  Processing ref.991.txt.
# 2019-06-14 03:35:10,166 [MainThread  ] [INFO ]  Processing ref.9910.txt.
# 2019-06-14 03:35:10,172 [MainThread  ] [INFO ]  Processing ref.9911.txt.
# 2019-06-14 03:35:10,177 [MainThread  ] [INFO ]  Processing ref.9912.txt.
# 2019-06-14 03:35:10,183 [MainThread  ] [INFO ]  Processing ref.9913.txt.
# 2019-06-14 03:35:10,188 [MainThread  ] [INFO ]  Processing ref.9914.txt.
# 2019-06-14 03:35:10,194 [MainThread  ] [INFO ]  Processing ref.9915.txt.
# 2019-06-14 03:35:10,199 [MainThread  ] [INFO ]  Processing ref.9916.txt.
# 2019-06-14 03:35:10,205 [MainThread  ] [INFO ]  Processing ref.9917.txt.
# 2019-06-14 03:35:10,211 [MainThread  ] [INFO ]  Processing ref.9918.txt.
# 2019-06-14 03:35:10,216 [MainThread  ] [INFO ]  Processing ref.9919.txt.
# 2019-06-14 03:35:10,221 [MainThread  ] [INFO ]  Processing ref.992.txt.
# 2019-06-14 03:35:10,227 [MainThread  ] [INFO ]  Processing ref.9920.txt.
# 2019-06-14 03:35:10,233 [MainThread  ] [INFO ]  Processing ref.9921.txt.
# 2019-06-14 03:35:10,239 [MainThread  ] [INFO ]  Processing ref.9922.txt.
# 2019-06-14 03:35:10,245 [MainThread  ] [INFO ]  Processing ref.9923.txt.
# 2019-06-14 03:35:10,250 [MainThread  ] [INFO ]  Processing ref.9924.txt.
# 2019-06-14 03:35:10,256 [MainThread  ] [INFO ]  Processing ref.9925.txt.
# 2019-06-14 03:35:10,261 [MainThread  ] [INFO ]  Processing ref.9926.txt.
# 2019-06-14 03:35:10,267 [MainThread  ] [INFO ]  Processing ref.9927.txt.
# 2019-06-14 03:35:10,272 [MainThread  ] [INFO ]  Processing ref.9928.txt.
# 2019-06-14 03:35:10,278 [MainThread  ] [INFO ]  Processing ref.9929.txt.
# 2019-06-14 03:35:10,283 [MainThread  ] [INFO ]  Processing ref.993.txt.
# 2019-06-14 03:35:10,288 [MainThread  ] [INFO ]  Processing ref.9930.txt.
# 2019-06-14 03:35:10,294 [MainThread  ] [INFO ]  Processing ref.9931.txt.
# 2019-06-14 03:35:10,300 [MainThread  ] [INFO ]  Processing ref.9932.txt.
# 2019-06-14 03:35:10,305 [MainThread  ] [INFO ]  Processing ref.9933.txt.
# 2019-06-14 03:35:10,311 [MainThread  ] [INFO ]  Processing ref.9934.txt.
# 2019-06-14 03:35:10,317 [MainThread  ] [INFO ]  Processing ref.9935.txt.
# 2019-06-14 03:35:10,322 [MainThread  ] [INFO ]  Processing ref.9936.txt.
# 2019-06-14 03:35:10,328 [MainThread  ] [INFO ]  Processing ref.9937.txt.
# 2019-06-14 03:35:10,333 [MainThread  ] [INFO ]  Processing ref.9938.txt.
# 2019-06-14 03:35:10,339 [MainThread  ] [INFO ]  Processing ref.9939.txt.
# 2019-06-14 03:35:10,345 [MainThread  ] [INFO ]  Processing ref.994.txt.
# 2019-06-14 03:35:10,350 [MainThread  ] [INFO ]  Processing ref.9940.txt.
# 2019-06-14 03:35:10,356 [MainThread  ] [INFO ]  Processing ref.9941.txt.
# 2019-06-14 03:35:10,361 [MainThread  ] [INFO ]  Processing ref.9942.txt.
# 2019-06-14 03:35:10,367 [MainThread  ] [INFO ]  Processing ref.9943.txt.
# 2019-06-14 03:35:10,373 [MainThread  ] [INFO ]  Processing ref.9944.txt.
# 2019-06-14 03:35:10,378 [MainThread  ] [INFO ]  Processing ref.9945.txt.
# 2019-06-14 03:35:10,384 [MainThread  ] [INFO ]  Processing ref.9946.txt.
# 2019-06-14 03:35:10,390 [MainThread  ] [INFO ]  Processing ref.9947.txt.
# 2019-06-14 03:35:10,395 [MainThread  ] [INFO ]  Processing ref.9948.txt.
# 2019-06-14 03:35:10,401 [MainThread  ] [INFO ]  Processing ref.9949.txt.
# 2019-06-14 03:35:10,406 [MainThread  ] [INFO ]  Processing ref.995.txt.
# 2019-06-14 03:35:10,412 [MainThread  ] [INFO ]  Processing ref.9950.txt.
# 2019-06-14 03:35:10,418 [MainThread  ] [INFO ]  Processing ref.9951.txt.
# 2019-06-14 03:35:10,423 [MainThread  ] [INFO ]  Processing ref.9952.txt.
# 2019-06-14 03:35:10,429 [MainThread  ] [INFO ]  Processing ref.9953.txt.
# 2019-06-14 03:35:10,434 [MainThread  ] [INFO ]  Processing ref.9954.txt.
# 2019-06-14 03:35:10,440 [MainThread  ] [INFO ]  Processing ref.9955.txt.
# 2019-06-14 03:35:10,445 [MainThread  ] [INFO ]  Processing ref.9956.txt.
# 2019-06-14 03:35:10,450 [MainThread  ] [INFO ]  Processing ref.9957.txt.
# 2019-06-14 03:35:10,456 [MainThread  ] [INFO ]  Processing ref.9958.txt.
# 2019-06-14 03:35:10,461 [MainThread  ] [INFO ]  Processing ref.9959.txt.
# 2019-06-14 03:35:10,467 [MainThread  ] [INFO ]  Processing ref.996.txt.
# 2019-06-14 03:35:10,472 [MainThread  ] [INFO ]  Processing ref.9960.txt.
# 2019-06-14 03:35:10,485 [MainThread  ] [INFO ]  Processing ref.9961.txt.
# 2019-06-14 03:35:10,490 [MainThread  ] [INFO ]  Processing ref.9962.txt.
# 2019-06-14 03:35:10,496 [MainThread  ] [INFO ]  Processing ref.9963.txt.
# 2019-06-14 03:35:10,501 [MainThread  ] [INFO ]  Processing ref.9964.txt.
# 2019-06-14 03:35:10,507 [MainThread  ] [INFO ]  Processing ref.9965.txt.
# 2019-06-14 03:35:10,512 [MainThread  ] [INFO ]  Processing ref.9966.txt.
# 2019-06-14 03:35:10,518 [MainThread  ] [INFO ]  Processing ref.9967.txt.
# 2019-06-14 03:35:10,523 [MainThread  ] [INFO ]  Processing ref.9968.txt.
# 2019-06-14 03:35:10,529 [MainThread  ] [INFO ]  Processing ref.9969.txt.
# 2019-06-14 03:35:10,534 [MainThread  ] [INFO ]  Processing ref.997.txt.
# 2019-06-14 03:35:10,540 [MainThread  ] [INFO ]  Processing ref.9970.txt.
# 2019-06-14 03:35:10,545 [MainThread  ] [INFO ]  Processing ref.9971.txt.
# 2019-06-14 03:35:10,551 [MainThread  ] [INFO ]  Processing ref.9972.txt.
# 2019-06-14 03:35:10,557 [MainThread  ] [INFO ]  Processing ref.9973.txt.
# 2019-06-14 03:35:10,562 [MainThread  ] [INFO ]  Processing ref.9974.txt.
# 2019-06-14 03:35:10,568 [MainThread  ] [INFO ]  Processing ref.9975.txt.
# 2019-06-14 03:35:10,573 [MainThread  ] [INFO ]  Processing ref.9976.txt.
# 2019-06-14 03:35:10,579 [MainThread  ] [INFO ]  Processing ref.9977.txt.
# 2019-06-14 03:35:10,584 [MainThread  ] [INFO ]  Processing ref.9978.txt.
# 2019-06-14 03:35:10,589 [MainThread  ] [INFO ]  Processing ref.9979.txt.
# 2019-06-14 03:35:10,595 [MainThread  ] [INFO ]  Processing ref.998.txt.
# 2019-06-14 03:35:10,601 [MainThread  ] [INFO ]  Processing ref.9980.txt.
# 2019-06-14 03:35:10,606 [MainThread  ] [INFO ]  Processing ref.9981.txt.
# 2019-06-14 03:35:10,612 [MainThread  ] [INFO ]  Processing ref.9982.txt.
# 2019-06-14 03:35:10,618 [MainThread  ] [INFO ]  Processing ref.9983.txt.
# 2019-06-14 03:35:10,623 [MainThread  ] [INFO ]  Processing ref.9984.txt.
# 2019-06-14 03:35:10,629 [MainThread  ] [INFO ]  Processing ref.9985.txt.
# 2019-06-14 03:35:10,635 [MainThread  ] [INFO ]  Processing ref.9986.txt.
# 2019-06-14 03:35:10,640 [MainThread  ] [INFO ]  Processing ref.9987.txt.
# 2019-06-14 03:35:10,646 [MainThread  ] [INFO ]  Processing ref.9988.txt.
# 2019-06-14 03:35:10,651 [MainThread  ] [INFO ]  Processing ref.9989.txt.
# 2019-06-14 03:35:10,656 [MainThread  ] [INFO ]  Processing ref.999.txt.
# 2019-06-14 03:35:10,662 [MainThread  ] [INFO ]  Processing ref.9990.txt.
# 2019-06-14 03:35:10,668 [MainThread  ] [INFO ]  Processing ref.9991.txt.
# 2019-06-14 03:35:10,673 [MainThread  ] [INFO ]  Processing ref.9992.txt.
# 2019-06-14 03:35:10,679 [MainThread  ] [INFO ]  Processing ref.9993.txt.
# 2019-06-14 03:35:10,684 [MainThread  ] [INFO ]  Processing ref.9994.txt.
# 2019-06-14 03:35:10,690 [MainThread  ] [INFO ]  Processing ref.9995.txt.
# 2019-06-14 03:35:10,695 [MainThread  ] [INFO ]  Processing ref.9996.txt.
# 2019-06-14 03:35:10,701 [MainThread  ] [INFO ]  Processing ref.9997.txt.
# 2019-06-14 03:35:10,706 [MainThread  ] [INFO ]  Processing ref.9998.txt.
# 2019-06-14 03:35:10,712 [MainThread  ] [INFO ]  Processing ref.9999.txt.
# 2019-06-14 03:35:10,718 [MainThread  ] [INFO ]  Saved processed files to C:\Users\Anatoly\AppData\Local\Temp\tmp53rdyvxn\model.
# 2019-06-14 03:39:21,610 [MainThread  ] [INFO ]  Written ROUGE configuration to C:\Users\Anatoly\AppData\Local\Temp\tmp8xl3sqy1\rouge_conf.xml
# 2019-06-14 03:39:21,610 [MainThread  ] [INFO ]  Running ROUGE with command perl E:\NIR\pyrouge\tools\ROUGE-1.5.5\ROUGE-1.5.5.pl -e E:\NIR\pyrouge\tools\ROUGE-1.5.5\data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m C:\Users\Anatoly\AppData\Local\Temp\tmp8xl3sqy1\rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.51489 (95%-conf.int. 0.51249 - 0.51720)
# 1 ROUGE-1 Average_P: 0.24265 (95%-conf.int. 0.24086 - 0.24438)
# 1 ROUGE-1 Average_F: 0.32132 (95%-conf.int. 0.31940 - 0.32312)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.21010 (95%-conf.int. 0.20743 - 0.21250)
# 1 ROUGE-2 Average_P: 0.09856 (95%-conf.int. 0.09725 - 0.09986)
# 1 ROUGE-2 Average_F: 0.13056 (95%-conf.int. 0.12899 - 0.13218)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.11623 (95%-conf.int. 0.11394 - 0.11837)
# 1 ROUGE-3 Average_P: 0.05493 (95%-conf.int. 0.05373 - 0.05607)
# 1 ROUGE-3 Average_F: 0.07247 (95%-conf.int. 0.07102 - 0.07393)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.07533 (95%-conf.int. 0.07323 - 0.07725)
# 1 ROUGE-4 Average_P: 0.03584 (95%-conf.int. 0.03480 - 0.03683)
# 1 ROUGE-4 Average_F: 0.04711 (95%-conf.int. 0.04582 - 0.04838)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.48158 (95%-conf.int. 0.47919 - 0.48393)
# 1 ROUGE-L Average_P: 0.22652 (95%-conf.int. 0.22482 - 0.22816)
# 1 ROUGE-L Average_F: 0.30016 (95%-conf.int. 0.29842 - 0.30195)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.20618 (95%-conf.int. 0.20496 - 0.20736)
# 1 ROUGE-W-1.2 Average_P: 0.16127 (95%-conf.int. 0.16013 - 0.16241)
# 1 ROUGE-W-1.2 Average_F: 0.17484 (95%-conf.int. 0.17388 - 0.17579)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.24421 (95%-conf.int. 0.24180 - 0.24655)
# 1 ROUGE-S* Average_P: 0.05891 (95%-conf.int. 0.05795 - 0.05986)
# 1 ROUGE-S* Average_F: 0.08776 (95%-conf.int. 0.08659 - 0.08887)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.25548 (95%-conf.int. 0.25306 - 0.25781)
# 1 ROUGE-SU* Average_P: 0.06218 (95%-conf.int. 0.06121 - 0.06313)
# 1 ROUGE-SU* Average_F: 0.09265 (95%-conf.int. 0.09147 - 0.09378)

# %% [markdown]
# model.load_model("cov_loss2")

# %% [markdown]
# test_generate(model,test_data, beam_width=4, mod=1)

# %% [markdown]
# r = Rouge155()
# r.system_dir = 'E:/NIR/drag/res1'
# r.model_dir = 'E:/NIR/drag/refs1'
# r.system_filename_pattern = 'res.(\d+).txt'
# r.model_filename_pattern = 'ref.A.#ID#.txt'
#
# output = r.convert_and_evaluate()
# print(output)
# output_dict = r.output_to_dict(output)

# %%
0.10897
# Out:
# 0.10897
